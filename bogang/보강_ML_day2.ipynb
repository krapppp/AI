# %%
import sklearn
import numpy as np
import pandas as pd

#1.데이터수집
#키 입력
키=[152,154,156,159,163,165,167,168,168,172,172,176,176,177,182,186,189,190]
#몸무게 결과
몸무게=[46,47,49,58,56,57,59,64,62,69,68,71,75,75,83,90,97,100]

data=pd.DataFrame(list(zip(키,몸무게)),columns=['키','몸무게'])

# %%
X=data[['키']].to_numpy()
y=data[['몸무게']].to_numpy()

# %%
from sklearn.tree import DecisionTreeRegressor
rg_m=DecisionTreeRegressor()
rg_m.fit(X,y)
# Out:
# DecisionTreeRegressor()

# %%
rg_m.score(X,y)
# Out:
# 0.9976487858280255

# %%
rg_m.predict(X)#예측값
# Out:
# array([ 46. ,  47. ,  49. ,  58. ,  56. ,  57. ,  59. ,  63. ,  63. ,
#         68.5,  68.5,  73. ,  73. ,  75. ,  83. ,  90. ,  97. , 100. ])

# %%
y.reshape(-1)#실제값
# Out:
# array([ 46,  47,  49,  58,  56,  57,  59,  64,  62,  69,  68,  71,  75,
#         75,  83,  90,  97, 100], dtype=int64)

# %%
data['성별']='여자 여자 여자 여자 여자 남자 남자 남자 여자 남자 여자 여자 여자 남자 남자 남자 남자 남자'.split()

# %%
data
# Out:
#       키  몸무게  성별
# 0   152   46  여자
# 1   154   47  여자
# 2   156   49  여자
# 3   159   58  여자
# 4   163   56  여자
# 5   165   57  남자
# 6   167   59  남자
# 7   168   64  남자
# 8   168   62  여자
# 9   172   69  남자
# 10  172   68  여자
# 11  176   71  여자
# 12  176   75  여자
# 13  177   75  남자
# 14  182   83  남자
# 15  186   90  남자
# 16  189   97  남자
# 17  190  100  남자

# %%
X=data.drop(['성별'],axis=1)
X
# Out:
#       키  몸무게
# 0   152   46
# 1   154   47
# 2   156   49
# 3   159   58
# 4   163   56
# 5   165   57
# 6   167   59
# 7   168   64
# 8   168   62
# 9   172   69
# 10  172   68
# 11  176   71
# 12  176   75
# 13  177   75
# 14  182   83
# 15  186   90
# 16  189   97
# 17  190  100

# %%
y=data[['성별']]
y
# Out:
#     성별
# 0   여자
# 1   여자
# 2   여자
# 3   여자
# 4   여자
# 5   남자
# 6   남자
# 7   남자
# 8   여자
# 9   남자
# 10  여자
# 11  여자
# 12  여자
# 13  남자
# 14  남자
# 15  남자
# 16  남자
# 17  남자

# %%
e_y=y.replace(['남자','여자'],[0,1])
e_y
# Out:
#     성별
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    0
# 6    0
# 7    0
# 8    1
# 9    0
# 10   1
# 11   1
# 12   1
# 13   0
# 14   0
# 15   0
# 16   0
# 17   0

# %%
X=X.to_numpy()

# %%
e_y=e_y.to_numpy()

# %%
X.shape,e_y.shape
# Out:
# ((18, 2), (18, 1))

# %%
from sklearn.tree import DecisionTreeClassifier
m=DecisionTreeClassifier()
m.fit(X,e_y)
# Out:
# DecisionTreeClassifier()

# %%
m.score(X,e_y)
# Out:
# 1.0

# %%
m.predict([[190,80]])
# Out:
# array([0], dtype=int64)

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
x1=X[:,0]
x2=X[:,1]

# %%
plt.scatter(x1,x2)
plt.scatter(190,80)

# %%
import matplotlib.pyplot as plt
plt.scatter(x1,x2)
plt.scatter(190,80)
plt.xlim(0,200)
plt.ylim(0,200)
# Out:
# (0.0, 200.0)

# %%
X
# Out:
# array([[152,  46],
#        [154,  47],
#        [156,  49],
#        [159,  58],
#        [163,  56],
#        [165,  57],
#        [167,  59],
#        [168,  64],
#        [168,  62],
#        [172,  69],
#        [172,  68],
#        [176,  71],
#        [176,  75],
#        [177,  75],
#        [182,  83],
#        [186,  90],
#        [189,  97],
#        [190, 100]], dtype=int64)

# %%
ss=MinMaxScaler()
ss.fit(X)
# Out:
# MinMaxScaler()

# %%
s_X=ss.transform(X)

# %%
x1=s_X[:,0]
x2=s_X[:,1]
plt.scatter(x1,x2)
ck_x=ss.transform([[190,80]])
ck_x1=ck_x[:,0]
ck_x2=ck_x[:,1]
plt.scatter(ck_x1,ck_x2)

# %%
y_1_x=data[data['성별']=='여자'][['키','몸무게']].to_numpy()
y_0_x=data[data['성별']!='여자'][['키','몸무게']].to_numpy()

# %%
y_1_x1=y_1_x[:,0]
y_1_x2=y_1_x[:,1]

# %%
y_0_x1=y_0_x[:,0]
y_0_x2=y_0_x[:,1]

# %%
plt.scatter(y_0_x1,y_0_x2,label='M')
plt.scatter(y_1_x1,y_1_x2,label='F')
plt.legend()
plt.show()

# %%
s_X
# Out:
# array([[0.        , 0.        ],
#        [0.05263158, 0.01851852],
#        [0.10526316, 0.05555556],
#        [0.18421053, 0.22222222],
#        [0.28947368, 0.18518519],
#        [0.34210526, 0.2037037 ],
#        [0.39473684, 0.24074074],
#        [0.42105263, 0.33333333],
#        [0.42105263, 0.2962963 ],
#        [0.52631579, 0.42592593],
#        [0.52631579, 0.40740741],
#        [0.63157895, 0.46296296],
#        [0.63157895, 0.53703704],
#        [0.65789474, 0.53703704],
#        [0.78947368, 0.68518519],
#        [0.89473684, 0.81481481],
#        [0.97368421, 0.94444444],
#        [1.        , 1.        ]])

# %%
s_X
# Out:
# array([[0.        , 0.        ],
#        [0.05263158, 0.01851852],
#        [0.10526316, 0.05555556],
#        [0.18421053, 0.22222222],
#        [0.28947368, 0.18518519],
#        [0.34210526, 0.2037037 ],
#        [0.39473684, 0.24074074],
#        [0.42105263, 0.33333333],
#        [0.42105263, 0.2962963 ],
#        [0.52631579, 0.42592593],
#        [0.52631579, 0.40740741],
#        [0.63157895, 0.46296296],
#        [0.63157895, 0.53703704],
#        [0.65789474, 0.53703704],
#        [0.78947368, 0.68518519],
#        [0.89473684, 0.81481481],
#        [0.97368421, 0.94444444],
#        [1.        , 1.        ]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
m=KNeighborsClassifier()
m.fit(X,y)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
m=KNeighborsClassifier(n_neighbors=3)
m.fit(X,y)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %%
m.predict([[174,60]])
# Out:
# array([0], dtype=int64)

# %%
y=data[['성별']].replace(['남자','여자'],[0,1]).to_numpy()

# %%
y.reshape(-1)==0
# Out:
# array([False, False, False, False, False,  True,  True,  True, False,
#         True, False, False, False,  True,  True,  True,  True,  True])

# %%
plt.scatter(X[y.reshape(-1)==0][:,0],X[y.reshape(-1)==0][:,1])
plt.scatter(X[y.reshape(-1)==1][:,0],X[y.reshape(-1)==1][:,1])
plt.scatter(174,60)
plt.show()
