# %% [markdown]
# # 1교시: 머신러닝 개념 도입 실습 (학생용)
#
# 아래 문제를 읽고 빈칸을 채우거나 입력해보세요. 각 문항은 머신러닝의 기본 개념을 복습하는 내용입니다.

# %% [markdown]
# ## 문제 1. 지도학습 vs 비지도학습 (선택형)
# 아래 보기 중 지도학습에 해당하는 항목을 모두 고르세요.

# %%
# 보기만 출력되고, 답은 직접 작성하세요.
print("""1. 정답 레이블이 제공된다.
2. 데이터를 군집으로 나눈다.
3. 회귀/분류 문제를 해결한다.
4. 사전에 라벨 없이 학습한다.""")

# 정답: 여기에 주석으로 작성해보세요.
# 예) 정답: 1, 3

# %% [markdown]
# ## 문제 2. 학습유형 분류하기

# %%
# 아래 학습 유형을 input()으로 입력해보세요.
print("스팸메일 분류 →", input("학습 유형: "))
print("고객 세분화 →", input("학습 유형: "))
print("게임 에이전트 자율 학습 →", input("학습 유형: "))

# %% [markdown]
# ## 문제 3. 분류 vs 회귀

# %%
# 각 항목을 분류(Classification) 또는 회귀(Regression) 중 하나로 분류해보세요.
print("내일 날씨 예측 (맑음/비/눈) →", input("유형: "))
print("아파트 가격 예측 →", input("유형: "))
print("스팸 여부 예측 →", input("유형: "))
print("혈당 수치 예측 →", input("유형: "))

# %% [markdown]
# ## 문제 4. 과소적합 vs 과대적합

# %%
# 다음 설명을 읽고 어떤 상황인지 input으로 작성하세요.
print("모델이 학습 데이터에서는 99% 정확도지만 테스트에서는 60%일 때 →", input("과대적합 or 과소적합: "))

# %% [markdown]
# ## 문제 5. 사례 유형 연결

# %%
# 문제별로 해당 유형을 입력해보세요 (분류 / 회귀 / 비지도 학습 등)
print("사진 속 동물 분류 →", input("유형: "))
print("자전거 수요 예측 →", input("유형: "))
print("리뷰 감성 분석 →", input("유형: "))
print("고객 세그먼트 분석 →", input("유형: "))

# %% [markdown]
# ## 문제 6. 용어 정리 (빈칸 채우기)

# %%
# 머신러닝 3대 분류와 지도학습이 주로 다루는 문제 유형을 적어보세요.
a = input("① 지도 / 비지도 / 강화 중 하나: ")
b = input("② 지도 / 비지도 / 강화 중 하나: ")
c = input("③ 지도 / 비지도 / 강화 중 하나: ")
d = input("④ 분류 / 회귀 중 하나: ")
e = input("⑤ 분류 / 회귀 중 하나: ")

print(f"머신러닝은 {a}, {b}, {c} 학습으로 나뉘며, 지도학습은 {d}, {e} 문제를 주로 해결한다.")
