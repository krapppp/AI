# %% [markdown]
# # 📘 머신러닝 분류 실습 (학생용)

# %% [markdown]
# ## 1. Iris 데이터셋 실습 (붓꽃 분류)
#
# 이번 실습에서는 `iris` 데이터를 사용하여 Decision Tree, KNN 모델의 분류 성능을 비교합니다.
#
# 빈칸을 직접 채워서 문법을 익히세요.

# %%
# 📦 라이브러리 불러오기
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# 📊 데이터 불러오기
data = load_iris()
X = data.____
y = data.____

# ✂️ 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=____, random_state=____)

# 🌲 Decision Tree 모델 훈련
tree_model = DecisionTreeClassifier()
tree_model.fit(____, ____)

# 🤖 KNN 모델 훈련
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(____, ____)

# 🎯 정확도 평가
print("Decision Tree 정확도:", tree_model.score(X_test, y_test))
print("KNN 정확도:", knn_model.score(X_test, y_test))

# %% [markdown]
# ### ✍️ 추가 질문

# %% [markdown]
# 1. iris 데이터셋의 타깃 클래스는 무엇인가요?
# 2. feature는 몇 개인가요?
# 3. test_size를 0.2로 바꾸면 어떤 일이 벌어지나요?
# 4. n_neighbors 값을 5로 바꾸면 결과는 어떻게 달라질까요?

# %% [markdown]
# ## 2. Wine 데이터셋 실습 (와인 종류 분류)
#
# 이번 실습에서는 `wine` 데이터를 사용하여 Decision Tree, KNN 모델의 분류 성능을 비교합니다.
#
# 빈칸을 직접 채워서 문법을 익히세요.

# %%
# 📦 라이브러리 불러오기
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# 📊 데이터 불러오기
data = load_wine()
X = data.____
y = data.____

# ✂️ 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=____, random_state=____)

# 🌲 Decision Tree 모델 훈련
tree_model = DecisionTreeClassifier()
tree_model.fit(____, ____)

# 🤖 KNN 모델 훈련
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(____, ____)

# 🎯 정확도 평가
print("Decision Tree 정확도:", tree_model.score(X_test, y_test))
print("KNN 정확도:", knn_model.score(X_test, y_test))

# %% [markdown]
# ### ✍️ 추가 질문

# %% [markdown]
# 1. wine 데이터셋은 어떤 feature들을 포함하나요?
# 2. 클래스는 몇 개인가요?
# 3. 모델 성능에 영향을 줄 수 있는 전처리 방법은 어떤 것이 있을까요?

# %% [markdown]
# ## 3. Breast Cancer 데이터셋 실습 (종양 진단)
#
# 이번 실습에서는 `breast_cancer` 데이터를 사용하여 Decision Tree, KNN 모델의 분류 성능을 비교합니다.
#
# 빈칸을 직접 채워서 문법을 익히세요.

# %%
# 📦 라이브러리 불러오기
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# 📊 데이터 불러오기
data = load_breast_cancer()
X = data.____
y = data.____

# ✂️ 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=____, random_state=____)

# 🌲 Decision Tree 모델 훈련
tree_model = DecisionTreeClassifier()
tree_model.fit(____, ____)

# 🤖 KNN 모델 훈련
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(____, ____)

# 🎯 정확도 평가
print("Decision Tree 정확도:", tree_model.score(X_test, y_test))
print("KNN 정확도:", knn_model.score(X_test, y_test))

# %% [markdown]
# ### ✍️ 추가 질문

# %% [markdown]
# 1. breast_cancer 데이터셋의 타깃은 어떤 값을 가지나요?
# 2. recall을 성능 평가 기준으로 사용해야 하는 이유는 무엇인가요?
# 3. 데이터가 불균형하다면 어떤 대처 방법이 있을까요?
