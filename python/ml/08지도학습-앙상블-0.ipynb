# %% [markdown]
# 1. Ensemble
# 1. 트리의 앙상블
#     1. 트리 앙상블: 랜덤 포레스트
#     1. 트리 앙상블: 엑스트라트리
# 1. Boosting알고리즘
#     1. AdBoost
#     1. 그레이디언트 부스팅
#     1. XGBoost
#     1. LightGBM
#     1. CatBoost

# %% [markdown]
# # 와인 데이터
#
# 와인중 레드와인, 화이트 와인이 있는데 색을 모르는 상태에서 와인을 분류활 수 있을까?
#
#  - 캘리포니아 어바인 대학에서 제공하는 와인 데이터세트를 이용해서 과정을 진행해 보자.
#  - 내장된 데이터세트가 없어서 외부 데이터를 사용하자.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate

# %%
# Wine data (simple)
wine = pd.read_csv('https://raw.githubusercontent.com/rickiepark/hg-mldl/master/wine.csv')

data = wine[['alcohol', 'sugar', 'pH']].to_numpy()
target = wine['class'].to_numpy()

X_train, X_test, y_train, y_test = \
    train_test_split(data, target, test_size=0.2, random_state=42)

# %% [markdown]
# # 앙상블 (Ensemble)
#
#
# 머신러닝의 학습 알고리즘에 사용되는 방법은 많은 부분 통계학의 방법을 사용하고 있다. 통계는 데이터의 샘플링, 해석, 처리와 그것을 바탕으로 전체 데이터를 이해할 수 있는 모델을 만드는 과정이다. 머신러닝도 학습 데이터를 분석하고 유용한 특징을 추출한 후 새로운 데이터를 예측할 수 있는 일반화된 모델을 만들어 간다.
#
#
# **앙상블 Enemble** (모델결합)은 ***여러 머신러닝 모델을 연결해 더 강력한 모델을 만드는 기법*** 이다. 앙상블 학습을 통한 분류는 여러 개의 분류기(Classifier)를 생성하고 그 예측을 결합함으로써 보다 정확한 최종 예측을 도출하는 기법을 말한다.
# - 여러 사람의 의견을 듣고 결정하는 집단 지성의 개념.
# - 모르는 지식을 얻기 위해서 무작정 학습하는 것 보다, 전문가의 조언이 빠르고, 선택의 범위를 좁힐 수 있다.
#
#
# 앙상블 학습 유형은 전통적으로 보팅(Voting), 배깅(bagging), 부스팅(boosting) 과 스태킹을 포함한 다양한 앙상블 방법이 있다.

# %% [markdown]
# ### 1) Boosting
#
# 부스팅이란 무작위로 선택하는 것 보다 약간 가능성이 높은 규칙(weak learner/classifier)들을 결합시켜 보다 정확한 예측 모델을 만들어 내는 것을 말한다. 즉 약한 것들을 여러개 결합해 강한 모델을 만들어 간다는 의미이다.
#
# > Boosting 역사는 1989년 Schapire가 제대로 된 모델을 발표했으며, 그루 Freund가 좀 더 효율적인 알고리즘을 발표한다. 부스팅은 주로 classification에 관련한 문제를 해결하기 위해 고안되었지만, 통계 등에도 사용하는 regression에도 사용할 수 있다. 일부는 90년대 개발된 최고의 머신러닝 알고리즘 중 하나라고 평가하고 있다. Schapire와 Freund는 AdaBoost(Adaptive boosting) 이라는 유명한 학습 알고리즘을 발표한다.

# %% [markdown]
# #### [부스팅의 학습 방법]
#
# weak learner 는 무작위로 선정하는 것 보다 성공 확률이 높은, 오차율이 50% 이하인 학습 규칙을 말한다. 약한 학습기를 선정하는 방법은 머신 러닝 알고리즘을 적용해 서로 다른 분포를 갖도록 해주는 것이다. 매번 기본 러닝 알고리즘을 적용할 때마다 새 약한 학습기를 만들며 이 과정을 반복적으로 수행한다. 반복 수행 후 약한 학습기를 부스팅 알고리즘으로 묶어서 strong learner를 만든다. 이 과정은 아래 그림 같은 과정을 반복한다:
#
#
#
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FclQ4UJ%2FbtqMDznC9E7%2Fqqwm92Jw6p4xQwcIhrAUKK%2Fimg.jpg' width='550'>

# %% [markdown]
# ### 2) Bagging (Bootstrap aggregating)
#
# 예를 들어 전세게 남성들의 평균 키를 구하는 경우를 생각해 보면, 제일 정확한 방법은 전세계 남자의 키를 잰 후 평균을 구하는 것일 것이다. 이것은 불가능 하기 때문에 적절한 방법을 통해 표본을 추출하고 그 표본에서 전세계 남성의 평균 키를 추정하는 것이 합리적인 대안이 될 것이다. 이런 과정을 ***Bootstrap*** 이라 하고,
#
# Bootstrapping은 전체 모집단의 분포를 확실하게 알 수 없는 경우 표본을 취한 후 그 표본이 전체 집단을 대표한다는 가정에서 전체의 분포를 예측할 수 있게 한다. 표본을 취하면 그 표본에 대한 본포는 정확하게 구할 수 있다. 표본이 전체를 대표하므로 표본에서 많은 횟수에 걸쳐 (동일한 갯수의) 샘플을 복원 추출(resample with replacement)한 후 각 샘플에 대한 분포를 구한다. 그 후 전체 표본의 분포와 샘플 간의 본포의 관계를 통해 전체 집단의 분포를 유추하는 방식이 부트스트래핑이며 1979년에 Bradley Efron 이 처음 언급하며 쓰이기 시작했다.
#
#
# <img src='https://miro.medium.com/v2/resize:fit:1400/1*4ybgcSuZqQ0L7qkRZiIR9Q.png' width=600>
#
#
# Bagging은 머신러닝 통계에 부트스트랩을 사용해 정확도를 높이고 안정선을 높이는 방식이다.

# %% [markdown]
# ### Bagging과 Boosting 차이
#
# 부스팅과 배깅은 모델결합(앙상블) 방식이라는 관점에서 동일하다
#  - 배깅은 부트스트랩이 서로 독립적인 관계를 갖는다.
#      - 하지만 부스팅은 순차적으로 처리가 되고, 에러가 발생하면 그 에러의 가중치를 올리기 위해 현재 weak learner가 이전 weak learner에 영향을 받는다.
#  - 부스팅은 최종적으로 weighed vote를 하지만 bagging은 단순 vote를 한다.
#  - bagging은 분산을 줄이는 것이 주 목적이지만, boosting은 바이어스를 줄이는 것이 목적이다.
#  - 잡음이 없는 데이터에 대해서 boostring이 bagging보다 우수하다
#  - Bagging 은 overfitting 문제를 해결할 수 있지만 Boosting 은 overfitting에서 자유롭지 못하다.

# %% [markdown]
# https://www.slideshare.net/freepsw/boosting-bagging-vs-boosting

# %% [markdown]
# ## - 앙상블 알고리즘 유형
#
# 머신러닝에 이런 종류 모델이 많지만 그 중 **랜덤 포레스트 Random Forest**와 **그래디언트 부스팅 Gradient boosting** 앙상블 모델이 분류와 회귀 문제의 다양한 데이터 세트에서 효과적이라 입증되었다. 랜덤 포레스트와 그래디언트 부스팅 결정 트리는 둘 다 모델을 구성하는 기본 요소로 결정 트리를 사용한다.
#
# **부스팅 계열 앙상블 알고리즘** 의 인기/강세가 이어져 - 캐글에서 매력적 솔루션으로 불리는 **XGBoost**, XGboost 와 유사한 예측 성능을 가지며 빠른 수행 속도를 가진 **LightGBM**, 여러 가지 모델의 결과를 기반으로 메타 모델을 수립하는 스태킹(stacking)을 포함해 다양한 유형의 앙상블 알고리즘이 머신러닝의 선도 알고리즘으로 인기를 얻고 있다.
#
# XGBoost, LightGBM 과 같은 최신 앙상블 모델 한 두 개만 알고 있어도 정형 데이터의 분류나 회귀 분야에서 예측 성능이 매우 뛰어난 모델을 쉽게 만들수 있다.

# %% [markdown]
# # 트리의 앙상블

# %% [markdown]
# ## - 랜덤포레스트
#
# 앙상블 알고리즘 중 비교적 빠른 수행 속도를 가진다. 랜덤 포레스트는 기본적으로 트리 기반으로 조금씩 다른 여러 **결정트리** 의 묶음이다. 결정트리의 쉽고 직관적 장점을 그대로 가지고 있다. 랜던포레스트 뿐만 아니라 부스팅 기반의 앙상블 알고리즘은 대부분 결정 트리 기반 알고리즘을 채택하고 있다.
#
# > 랜덤 포레스트(Random Forest, Randomized trees)는 2001년 레오 브라이만(Leo Breiman)이 제안한 머신러닝 알고리즘이다. 집단 학습을 기반으로 고정밀 분류, 회귀, 클러스터링 등을 구현한다.
#
# 이름 자체로 유추할 수 있듯 랜덤 포레스트는 ***결정 트리를 랜덤하게 만들어 결정 트리의 숲을 만든다*** . 그리고 각 결정 트리의 예측을 사용해 최종 예측을 만든다.

# %% [markdown]
# <img src='https://i.imgur.com/bkbxgNC.png' width=600>
#  - https://www.tibco.com/reference-center/what-is-a-random-forest
#
# 학습 전용 데이터를 기반으로 다수의 의사결정 트리를 만들고 만들어진 의사결정 트리를 기반으로 다수결로 결과를 유도하므로 높은 정밀도를 자랑한다. 학습 데이터를 무작위로 샘플링해서 만들어진 다수의 의사결정 트리를 사용하기 때문에 랜덤 포레스트라고 불린다. 의사결정 트리는 일반적으로 부정확한 학습 방법으로 분류되지만 집단 학습을 하면 정밀도를 굉장히 높일 수 있다.

# %% [markdown]
# 랜덤 포레스트는 훈련 데이터에 **과대적합을 회피할 수** 있는 방법이다. 각 트리는 비교적 정확한 예측을 할 수 있지만 데이터의 일부에 과대적합하는 경향을 가진다는데 기초한다. 즉 잘 작동해서 **_서로 다른 방향으로 과대적합된 트리를 많이 만들면 그 결과를 평균해서 과대적합한 양을 줄일 수 있다_**. 이렇게 하면 트리 모델의 예측 성능이 유지 되면서 과대적합이 줄어드는 것이 수학적으로 증명되었다.

# %% [markdown]
# 이런 전략을 구현하려면 결정 트리를 많이 만들고 각각 트리는 타깃 예측을 잘 해야 하고, 다른 트리와 구별되야 한다. 랜덤 포레스트는 서로 달라 지도록 무작위로 트리 생성을 한다. 각 트리에 데이터 포인트를 무작위로 선택하는 것과 분할 테스트에서 특성을 무작위로 선택하는 방법이 있다.

# %% [markdown]
# 랜덤 포레스트는 훈련을 통해 구성해놓은 다수의 나무들로부터 분류 결과를 취합해서 결론을 얻는, 일종의 인기 투표(?) 같은 거다.
#
# <img src='https://i.imgur.com/piPMmFv.png' width=600>
#  - https://hleecaster.com/ml-random-forest-concept/

# %% [markdown]
# 랜덤 포레스트는  결정 트리를 랜덤하게 만들어 각 결정 트리를 훈련하기 위한 데이터를 랜덤하게 만드는데, 이 데이터를 만드는 방법이 독특하다. 우리가 입력한 훈련 데이터에서 랜덤하게 샘플을 추출하여 훈련 데이터를 만든다. 이때 한 샘플이 중복되어 추출될 수도 있다. 이렇게 만들어진 샘플을 **부트스트랩 샘플** 이라고 부른다.
#
# <img src='https://i.imgur.com/FV5cjUM.png' width=600>
#
#  - https://velog.io/@vvakki_/%EB%9E%9C%EB%8D%A4-%ED%8F%AC%EB%A0%88%EC%8A%A4%ED%8A%B8%EC%97%90%EC%84%9C%EC%9D%98-%EB%B3%80%EC%88%98-%EC%A4%91%EC%9A%94%EB%8F%84Variable-Importance-3%EA%B0%80%EC%A7%80

# %% [markdown]
# 또한 각 노드를 분할할 때 전체 특성 중에서 일부 특성을 무작위로 고른 다음 이 중에서 최선의 분할을 찾는다. 분류 모델인 RandomForestClassifier는 기본적으로 전체 특성 개수의 제곱근만큼의 특성을 선택한다. 즉 4개의 특성이 있다면 2개를 랜덤하게 선택하여 사용한다. 다만 회귀 모델인 RandomForestRegressor는 전체 특성을 사용한다.
#
# 사이킷런의 랜덤 포레스트는 기본적으로 100개의 결정 트리를 이런 방식으로 훈련한다. 그다음 분류일 때는 각 트리의 클래스별 확률을 평균하여 가장 높은 확률을 가진 클래스를 예측으로 삼는다. 회귀일 때는 각 트리의 예측을 평균한다.
#
# 랜덤 포레스트는 랜덤하게 선택한 샘플과 특성을 사용하기 때문에 훈련 세트에 과대적합되는 것을 막아주고 검증 세트와 테스트 세트에서 안정적인 성능을 얻을 수 있다. 기본 매개변수만으로도 아주 좋은 결과를 낸다.

# %% [markdown]
# ### 랜덤포레스트 장.단점
#
# <장점>
#  - 분류,회귀 모두 널리 쓰이고 성능과 정확도 좋다
#  - 간편하고 빠르다
#  - 큰 데이터 세트에도 잘 되고 많은 입력 변수를 다룰 수 있ㄷ.
#
# <단점>
#  - 속도와 메모리 비용이 상대적(선형분류 대비)으로 크다
#  - 많은 트리는 큰 시간과 메모리 소비
#  - 트리 깊이 개수 설정이 잘못되면 과적합 발생

# %% [markdown]
# ## 랜덤포레스트 와인 분류
#
# 이제 사이킷런의 RandomForestClassifier 클래스를 화이트 와인을 분류하는 문제에 적용해 보자.
#
# ```python
# class RandomForestClassifier(
#     n_estimators: Int = 100,
#     *,
#     criterion: Literal['gini', 'entropy', 'log_loss'] = "gini",
#     max_depth: Int | None = None,
# )
# ```

# %% [markdown]
# RandomForestCalssifier는 기본적으로 100개의 결정 트리를 사용한다. n_jobs 매개변수를 -1로 지정하여 모든 CPU 코어를 사용하는 것이 좋다. cross_validate() 함수를 사용해 교차 검증을 해보자. return_train_score 매개변수를 True로 지정하면 검증 점수 뿐만 아니라 훈련 세트에 대한 점수도 같이 반환한다.

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier
# Out:
# 0.9973541965122431 0.8905151032797809

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(n_jobs=-1,random_state=50)
scores=cross_validate(rf,X_train,y_train,return_train_score=True,n_jobs=-1)
np.mean(scores['train_score']),np.mean(scores['test_score'])
# Out:
# (np.float64(0.9974503966084433), np.float64(0.8882074109720884))

# %% [markdown]
# 출력된 결과를 보면 훈련 세트에 과대적합된 것 같다

# %% [markdown]
# #### 특성 중요도
#
# 랜덤 포레스트는 결정 트리의 앙상블이기 때문에 DecisionTreeClassifier가 제공하는 중요한 매개변수를 모두 제공한다. criterion, max_depth, max_features, min_samples_split, min_impurity_decrease, min_samples_leaf 등이다.
#
# 또한 결정트리의 큰 장점 중 하나인 특성 중요도를 계산한다. 특성 중요도는 데이터 컬럼에 해당하는 특성에 대해서, 각 결정 트리의 특성 중요도를 취합한 것이다.
#
# 랜덤 포레스트 객체의 `.feature_importances_` 속성으로 중특성 중요도를 산출한다. 앞의 랜덤 포레스트 모델을 훈련 세트에 훈련한 후 특성 중요도를 출력해 보자.

# %%
# Out:
# [0.23167441 0.50039841 0.26792718]

# %%
rf.fit(X_train,y_train)
rf.feature_importances_
# Out:
# array([0.23185421, 0.50084747, 0.26729831])

# %% [markdown]
# 앞서 결정 트리에서 만든 특성 중요도와 비교해보면 각 특성 알코올도수, 당도, pH에서, 두 번째 특성인 당도의 중요도가 감소하고 알코올 도수와 pH특성의 중요도가 조금 상승했다. 이런 이유는 랜덤 포레스트가 특성의 일부를 랜덤하게 선택하여 결정 트리를 훈련하기 때문이다. 그 결과 하나의 특성에 과도하게 집중하지 않고 좀 더 많은 특성이 훈련에 기여할 기회를 얻는다. 이는 과대적합을 줄이고 일반화 성능을 높이는데 도움이 된다.

# %% [markdown]
# #### OOB 샘플
#
# RandomForestClassifier에는 재미있는 기능이 하나 더 있는데, 자체적으로 모델을 평가하는 점수를 얻을 수 있다. 랜덤 포레스트는 훈련 세트에서 중복을 허용하여 부트스트랩 샘플을 만들어 결정 트리를 훈련한다고 했다. 이때 부트스트랩 샘플에 포함되지 않고 남는 샘플이 있다. 이런 샘플을 OOB 샘플이라고 한다. 이 점수를 얻으려면 RandomForestClassifier 클래스의 oob_score 매개변수를 True로 지정해야한다. 이렇게 하면 랜덤 포레스트는 각 결정 트리의 OOB 점수를 평균하여 출력한다.

# %%
# Out:
# 0.8934000384837406

# %%
rf=RandomForestClassifier(oob_score=True,n_jobs=-1,random_state=50)
rf.fit(X_train,y_train)
rf.oob_score_
# Out:
# 0.8951318068116221

# %% [markdown]
# 교차 검증에서 얻은 점수와 매우 비슷한 결과를 얻었다. ***OOB 점수를 사용하면 교차 검증을 대신할 수 있어서 결과적으로 훈련 세트에 더 많은 샘플을 사용할 수 있다*** .

# %% [markdown]
# ### ex) GridSearchCV 적용 실습
#
# 트리 기반 앙상블 알고리즘의 단점으로 하이퍼파라미터가 너무 많아서 튜닝에 많은 시간을 소모하는 것이다. 튜닝에 많으 시간을 들여보 성능이 크게 향상되지 않는 점이 아쉽다. 여기에 배깅, 부스팅, 학습, 정규화 등을 위한 하이퍼 파라미터까지 추가되므로 일반적으로 다른 ML 알고리즘에 비해 많을 수 밖에 없다.
#
# 랜덤포레스트의 결정트리 파라미터와 거의 동일
# - n_estimators: 결정 트리 개수. 기본 10개.
# - max_features: 결정 트리와 같다. 기본 auto로 전체 피처가 아니라 sqrt(전체개수) 만큼 참조
# - max_depth, min_samples_leaf

# %% [markdown]
# 이번에는 GridSearchCV 를 이용해 랜덤포레스트의 하이퍼 파라미터를 튜닝해 보자, 멀티코어 환경에서 RandomForestClassifier, GridSearchCV 의 인자 `n_jobs=-1` 파라미터를 사용하면 모든 CPU 코어를 사용할 수 있다.
#
# 다음 같이 주었을 때 Macbook pro 에서
#  - 8코어: 50초 정도,
#  - 4코어 사용: 58초 정도
#
# 랜덤포레스트는 병렬 처리도 효과적으로 처리되서 뒤에 나오는 그래디언트 부스팅 보다 예측 성능이 약간 떨어져도 랜덤 포레스트로 일단 기반 모델을 먼저 구축하는 경우가 많다.

# %%
# %%time
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 20, 'n_estimators': 100}
# 최고 예측 정확도: 0.8722
# CPU times: user 694 ms, sys: 225 ms, total: 919 ms
# Wall time: 12.3 s

# %%
# %%time
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

params={'n_estimators':[100], 'max_depth':[6,8,10,12],'min_samples_leaf':[8,12,18],'min_samples_split':[8,16,20]}
rf_clf=RandomForestClassifier(random_state=50,n_jobs=-1)
grid_cv=GridSearchCV(rf_clf,param_grid=params,cv=2,n_jobs=-1)
grid_cv.fit(X_train,y_train)
# Out:
# CPU times: total: 1.75 s
# Wall time: 22.6 s
# GridSearchCV(cv=2, estimator=RandomForestClassifier(n_jobs=-1, random_state=50),
#              n_jobs=-1,
#              param_grid={'max_depth': [6, 8, 10, 12],
#                          'min_samples_leaf': [8, 12, 18],
#                          'min_samples_split': [8, 16, 20],
#                          'n_estimators': [100]})

# %%
grid_cv.best_params_,grid_cv.best_score_
# Out:
# ({'max_depth': 10,
#   'min_samples_leaf': 8,
#   'min_samples_split': 8,
#   'n_estimators': 100},
#  np.float64(0.872425691648443))

# %%
clf=grid_cv.best_estimator_
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=8, min_samples_split=8,
#                        n_jobs=-1, random_state=50)

# %%
from sklearn.metrics import accuracy_score
# Out:
# 최고 예측 정확도: 0.8646

# %%
from sklearn.metrics import accuracy_score, classification_report
pred=clf.predict(X_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.72      0.73       341
#          1.0       0.90      0.92      0.91       959
#
#     accuracy                           0.86      1300
#    macro avg       0.83      0.82      0.82      1300
# weighted avg       0.86      0.86      0.86      1300

# %% [markdown]
# 피처의 중요도를 가시화 해보자,

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(8,6))
plt.title('Feature Importances Top 20')


plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ft_importances = pd.Series(clf.feature_importances_, index=['alcohol','sugar','pH'])
ft_top20 = ft_importances.sort_values(ascending=False)[:20] #top 20

plt.figure(figsize=(8,6))
plt.title('Feature Importances Top 20')
sns.barplot(x=ft_top20, y=ft_top20.index)
plt.show()

# %% [markdown]
# ## - 엑스트라트리
#
# Extra Tree 는 랜덤 포레스트와 매우 비슷하게 동작한다. 기본적으로 100개의 결정 트리를 훈련한다. 랜덤 포레스트와 동일하게 결정 트리가 제공하는 대부분의 매개변수를 지원한다. 또한 전체 특성 중에 일부 특성을 랜덤하게 선택하여 노드를 분할하는 데 사용한다. 랜덤 포레스트와 엑스트라 트리의 차이점은 ***부트스트랩 샘플을 사용하지 않는다*** 는 점이다.
#
# 즉 각 결정 트리를 만들 때 전체 훈련 세트를 사용한다. 대신 노드를 분할할 때 가장 좋은 분할을 찾는 것이 아니라 무작위로 분할한다. 엑스트라 트리가 사용하는 결정트리는 splitter='random'인 결정트리이다. ***하나의 결정 트리에서 특성을 무작위로 분할한다면 성능은 낮아지겠지만 많은 트리를 앙상블 하기 때문에 과대적합을 막고 검증 세트의 점수를 높이는 효과가 있다*** .
#
# 엑스트라 트리가 무작위성이 좀 더 크기 때문에 랜덤 포레스트보다 더 많은 결정 트리를 훈련해야 한다. 하지만 랜덤으로 노드를 분할하기 때문에 빠른 계산 속도가 엑스트라 트리의 장점이다.
#
# 사이킷런에서 제공하는 엑스트라 트리는 ExtraTreesClassifier 이다.

# %%
from sklearn.ensemble import ExtraTreesClassifier
# Out:
# 0.9974503966084433 0.8887848893166506

# %%
from sklearn.ensemble import ExtraTreesClassifier

et=ExtraTreesClassifier(n_jobs=-1,random_state=50)
scores1=cross_validate(et,X_train,y_train,return_train_score=True,n_jobs=-1)
np.mean(scores1['train_score']),np.mean(scores1['test_score'])
# Out:
# (np.float64(0.9974503966084433), np.float64(0.8860909158214259))

# %%
et.fit(X_train,y_train)

# %% [markdown]
# 랜덤 포레스트와 비슷한 결과가 나왔다. 와인 예제는 특성이 많지 않아 두 모델의 차이가 크지 않다.

# %% [markdown]
# 엑스트라 트리도 랜덤 포레스트와 마찬가지로 특성 중요도를 제공한다. 알코올 도수, 당도, pH 순서 인데 결과를 보면 엑스트라 트리도 결정 트리보다 당도에 대한 의존성이 작다.

# %% [markdown]
# 엑스트라 트리의 회귀 버전은 ExtraTreesRegressor 클래스이다.

# %% [markdown]
# # Boosting 알고리즘
#
# 부스팅은 전체 모델 성능을 향상시키기 위해 여러 모델이 반복적으로 추가되는 순차 앙상블 학습 기술입니다. 부스팅알고리즘은 약한 학습기를 순차적으로 학습-예측 하면서 잘못 예측한 데이터에 가중치 부여를 통해 오류를 개선해 나가며 학습하는 방식이다. 부스팅의 대표적인 구현은 AdaBoost(Adaptive Boosting)과 Gradient Boosting 이 있다.
#
# ![image.png](attachment:7a33c67f-ccb6-485d-871d-e558ba32f1ca.png)
#  - 부스팅 알고리즘의 발전
#
#  Light Gbm과 CatBoost는 비슷한 타이밍에 출시되었으므로 하나가 다른 버전의 개선 된 버전이라고 말할 수 없습니다.

# %% [markdown]
# ## - AdaBoost
#
# AdaBoost는 적응 형 부스팅의 약자입니다. 적응 형이라고 부르는 이유는 알고리즘 이 이전 모델에서 분류되지 않은 케이스를 활용하고 분류되지 않은 케이스가 더 많은 가중치를 갖는 새로운 가중치 데이터 샘플 을 생성하기 때문 입니다. 이런 식으로 새로 추가 된 모델은 이전 모델의 '실수'를 해결하는 데 더 적응해야합니다.
#
# AdaBoost는 개발 된 가장 초기의 부스팅 알고리즘 중 하나입니다. 요즘 거의 사용되지 않지만 대부분의 부스팅 알고리즘의 기초입니다.
#
# ![image.png](attachment:4a8a8f84-6894-4af6-a11f-86a26f731344.png)

# %% [markdown]
# AdaBoost 는 오류 데이터에 가중치를 부여하며 부스팅을 수행한다.
#
# 참조: https://www.slideshare.net/freepsw/boosting-bagging-vs-boosting
#
# <img src='https://image.slidesharecdn.com/mlstudyboostingv0-171128021615/95/boosting-bagging-vs-boosting-15-1024.jpg?cb=1511939004' width='600'>

# %% [markdown]
# 위 그림 같이 +,- 로 된 피처 데이터 세트가 있다면
# - Model1 학습기에서 위/아래로 수평 분류했을 때 잘못분류된 오류 데이터가 있다.
#     - 다음 학습기를 위해 데이터 세트에 잘못 예측한 데이터에 가중치 부여한다.
# - Model2 학습기에서 수직으로 분류 했을 때 잘못 분류된 오류 데이터
#     - 데이터 세트에 잘못 예측한 데이터에 가중치 부여해 다음 학습기에 전달
# - Model3 학습기에서 +,-로 분류하고 오류 데이터를 찾는다.
# - 오른쪽 같이 1-3 학습기의 결합한 예측 결과다. 각 개별 학습기 보다 정확해 졋다.
#
# 각 개별 학습기 Model1~3 는 오른쪽 처럼 각각 가중치를 부여해 결합한다. 첫번째 학습기에 가중치 0.3, 두번째 0.5, 세번째 0.4 를 부여한 후 모두 결합해 예측을 수행한다.

# %%
from sklearn.ensemble import AdaBoostClassifier
# Out:
# Accuracy of the result is:
# 0.8484615384615385

# %%
from sklearn.ensemble import AdaBoostClassifier

clf=AdaBoostClassifier(n_estimators=100,random_state=50)
clf.fit(X_train,y_train)
pred_ada=clf.predict(X_test)
print(classification_report(y_test,pred_ada))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.70      0.71       341
#          1.0       0.89      0.90      0.90       959
#
#     accuracy                           0.85      1300
#    macro avg       0.80      0.80      0.80      1300
# weighted avg       0.85      0.85      0.85      1300

# %% [markdown]
# ## - GBM (Gradient Boosting Machine)
#
# 그레이디언트 부스팅은 깊이가 얕은 결정 트리를 사용하여 이전 트리의 오차를 보완하는 방식으로 앙상블 하는 방법이다.
#
# - 부스팅 알고리즘은 여러 개의 약한 학습기를 순차적으로 학습 예측하면서 잘못 예측한 데이터에 가중치를 부여해서 오류를 개선해 나가는 방식
# - GBM은 가중치를 업데이트할때 경사 하강법을 사용하는것이 큰 차이
#
# AdaBoost와 비교하여 그래디언트 부스팅은 분류되지 않은 케이스에 불이익을주지 않고 대신 손실 함수를 사용합니다. 손실 함수는 회귀에 대한 평균 평균 오류이거나 분류 문제에 대한 로그 손실 일 수 있습니다. 또한 경사 부스팅 알고리즘은 경사 하강 법을 사용하여 손실 함수를 지속적으로 최소화하여 최적의 지점을 찾습니다.
#
# ![image.png](attachment:120d3c7a-c08a-4743-a96a-15331b871e41.png)
#
# Gradient Boosting 방법은 이론적으로 AdaBoost보다 성능이 좋습니다. 그러나 과적 합 문제가 발생하기 쉽고 그라디언트 부스팅의 경우 런타임이 더 길어집니다. 조기 중지 조건을 설정하여 과적 합을 완화하고 런타임도 줄일 수 있습니다.

# %% [markdown]
# GBM은 CART 기반의 다른 알고리즘과 마찬가지로 분류/회귀가 가능하다. 사이킷런은 GradientBoostingClassifier 를 제공한다.

# %% [markdown]
# ### GradienBoostingClassifier 사용
#
# 사이킷런의 GradienBoostingClassifier는 기본적으로 깊이가 3인 결정 트리를 100개 사용한다. ***깊이가 얕은 결정 트리를 사용하기 때문에 과대적합에 강하고 일반적으로 높은 일반화 성능을 기대할 수 있다*** .
#
# > 참고: https://bkshin.tistory.com/entry/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D-15-Gradient-Boost
#
# 앞서 배웠던 경사 하강법을 사용하여 트리를 앙상블에 추가한다. 분류에서는 로지스틱 손실 함수를 사용하고 회귀에서는 평균 제곱 오차 함수를 사용한다. 그레이디언트 부스팅은 결정 트리를 계속 추가하면서 가장 낮은 곳을 찾아 이동한다.

# %% [markdown]
# ```python
# class GradientBoostingClassifier(
#     *,
#     loss: Literal['log_loss', 'deviance', 'exponential'] = "log_loss",
#     learning_rate: Float = 0.1,
#     n_estimators: Int = 100,
#     subsample: Float = 1,
#     criterion: Literal['friedman_mse', 'squared_error'] = "friedman_mse",
#     min_samples_split: float = 2,
#     min_samples_leaf: float = 1,
# )
# ```

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Out:
# 0.8881086892152563 0.8720430147331015

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier(random_state=50)
gb.fit(X_train,y_train)
pred_gb=gb.predict(X_test)
print(classification_report(y_test,pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.73      0.74       341
#          1.0       0.91      0.92      0.91       959
#
#     accuracy                           0.87      1300
#    macro avg       0.83      0.82      0.83      1300
# weighted avg       0.87      0.87      0.87      1300

# %% [markdown]
# 과대적합이 거의 되지 않았다. 그레이디언트 부스팅은 결정 트리의 개수를 늘려도 과대적합에 매우 강하다. 학습률을 증가시키고 트리의 개수를 늘리면 조금 더 성능이 향상될 수 있다.

# %%
# Out:
# 0.9464595437171814 0.8780082549788999

# %%
# Out:
# [0.15887763 0.6799705  0.16115187]

# %% [markdown]
# 결과를 보면 랜덤 포레스트보다 당도에 더 집중한다.

# %% [markdown]
# #### subsample
#
# 재미있는 매개변수가 하나 더 있다. 트리 훈련에 사용할 훈련 세트의 비율을 정하는 subsample이다. 이 매개변수의 기본값은 1.0으로 전체 훈련 세트를 사용한다. 하지만 subsample이 1보다 작으면 훈련 세트의 일부를 사용한다. 이는 마치 경사 하강법 단계마다 일부 샘플을 랜덤하게 선택하여 진행하는 확률적 경사 하강법이나 미니배치 경사 하강법과 비슷하다.

# %%
# Out:
# 0.9463633551918373 0.877815577108166
# [0.17849048 0.638021   0.18348852]

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb2=GradientBoostingClassifier(random_state=42)
scores3=cross_validate(gb2,X_train,y_train,return_train_score=True,n_jobs=-1)
print(np.mean(scores3['train_score']),np.mean(scores3['test_score']))

gb2.fit(X_train,y_train)
gb2.feature_importances_
# Out:
# 0.8881086892152563 0.8720430147331015
# array([0.11949946, 0.74871836, 0.13178218])

# %% [markdown]
# ### ex) GBM에서 하이퍼 파라미터 튜팅
#
# 트리 기반의 기본 파라미터에 더해서 경사하강법에 관련한 파라미터들:
#
# - loss: 경사하강법에 사용할 비용 함수를 지정. 기본 deviance 를 사용.
# - learning_rate: 학습 진행시 적용하는 학습률로 0~1 사이로 기본은 0.1이다.
#     - 너무 작은 값은 예측 성능이 높아질 수 있으나 수행 시간이 오래 걸린다.
#     - n_estimators 와 상호보완적으로 조합해 사용한다. 학습률을 작게하고 n_estimators를 크게하면 한계까지 예측 성능이 조금씩 좋아질 수 잇다. 하지만 수행ㄱ시간이 오래 걸리는 단점과 성능이 현격히 좋지는 않다.
# - n_estimators: weak learner 갯수. weak learner 가 순차적으로 오류 보정하므로 크면 예측 성능이 좋아질 수 있다. 수행시간이 오래 걸릴 수 있다. 기본 100.
# - subsample: weak learner 가 학습에 사요하는 데이터의 샘플링 비율. 기본 1로 100% 사용한다. 과적합이 염려되면 이를 1보다 작은 값으로 설정한다.

# %% [markdown]
# GridSearchCV 를 이용해 하이퍼파라미터를 최적화 해보자. 사용자 행동 데이터 세트 같이 데이터 양이 많은 것을 GBM 으로 테스트 하려면 시간이 많이 걸린다. 여기서는 간략히 하겠다.

# %%
# %%time
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# 결과로 도출되는 하이퍼파라미터 성능.

# %% [markdown]
# GradientSearchCV 에 의해 learning_rate=0.05, n_estimators=500 일 때 2개의 교차 검증 세트에서 90.1% 정확도로 최고가 나왔다. 이 설정으로 적용해 예측 정확도를 확인해 보자,,,

# %%
# GridSearchCV를 이용하여 최적으로 학습된 estimator로 predict 수행.

# %% [markdown]
# ## - 히스토그램 기반 부스팅
#
# 히스토그램 기반 그레이디언트 부스팅은 정형 데이터를 다루는 머신러닝 알고리즘 중에 가장 인기가 높은 알고리즘이다. 히스토그램 기반 그레이디언트 부스팅은 먼저 입력 특성을 256개의 구간으로 나눈다. 따라서 노드를 분할할 때 최적의 분할을 매우 빠르게 찾을 수 있다. 히스토그램 기반 그레이디언트 부스팅은 256개의 구간 중에서 하나를 떼어놓고 누락된 값을 위해서 사용한다. 따라서 입력에 누락된 특성이 있더라도 이를 따로 전처리할 필요가 없다.

# %% [markdown]
# 사이킷런의 히스토그램 기반 그레이디언트 부스팅 클래스는 HistGradientBoostingClassifier이다. 일반적으로 HistGradientBoostingClassifier는 기본 매개변수에서 안정적인 성능을 얻을 수 있다. HistGradientBoostingClassifier에는 트리의 개수를 지정하는데 n_estimators 대신에 부스팅 반복 횟수를 지정하는 max_iter를 사용한다.

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hgb=HistGradientBoostingClassifier(random_state=50)
scores=cross_validate(hgb,X_train,y_train,return_train_score=True,n_jobs=-1)
print(np.mean(scores['train_score']),np.mean(scores['test_score']))
# Out:
# 0.9321723946453317 0.8801241948619236

# %% [markdown]
# 과대 적합을 잘 억제하면서 그레이디언트 부스팅보다 조금 더 높은 성능을 제공한다.

# %% [markdown]
# 스토그램 기반 그레이디언트 부스팅의 특성 중요도를 계산하기 위해 permutation_importace() 함수를 사용하자. 이 함수는 특성을 하나씩 랜덤하게 섞어서 모델의 성능이 변화하는지를 관찰하여 어떤 특성이 중요한지를 계산한다. 먼저 히스토그램 기반 그레이디언트 부스팅 모델을 훈련하고 훈련 세트에서 특성 중요도를 계산해보자. n_repeats 매개변수는 랜덤하게 섞을 횟수를 지정한다. 여기선 10으로 지정하자. 기본값은 5이다.

# %%
from sklearn.inspection import permutation_importance
# Out:
# [0.08876275 0.23438522 0.08027708]

# %% [markdown]
# permutation_importance() 함수가 반환하는 객체는 반복하여 얻은 특성 중요도, 평균, 표준편차를 담고있다. 평균을 출력해보면 랜덤 포레스트와 비슷한 비율임을 알 수 있다.
#
# 이번엔 테스트 세트에서 특성 중요도를 계산해 보자.

# %%
# Out:
# [0.05969231 0.20238462 0.049     ]

# %% [markdown]
# 테스트 세트의 결과를 보면 그레이디언트 부스팅과 비슷하게 조금 더 당도에 집중하고 있다는 것을 알 수 있다. 그럼 HistGradientBoostingClassifier를 사용하여 테스트 세트에서의 성능을 최종적으로 확인해 보자.

# %%
# Out:
# 0.8723076923076923

# %% [markdown]
# ## - XGBoost
#
# XGBoost는 Extreme Gradient Boosting의 약자로, 그래디언트 부스팅 방법에 대한 계산 리소스의 한계를 뛰어 넘는 엔지니어의 목표를 나타냅니다.
#
# XGBoost는 그래디언트 부스팅 방법의 향상된 버전입니다. 첫째, 정규화를 사용하여 과적 합을 개선합니다. 둘째, 병렬 실행을 사용하여 정렬을 최적화하여 런타임 속도를 향상시킵니다. 마지막으로 의사 결정 트리의 최대 깊이를 매개 변수로 사용하여 트리를 정리하여 런타임을 크게 줄입니다.
#
# - 여러개의 Decision Tree를 조합해서 사용하는 Ensemble 알고리즘
# - XGBoost에서 tree_method를 hist로 지정하면 히스토그램 기반 그레이디언트 부스팅 알고리즘을 쓸 수 있다.

# %%
# %pip install xgboost
# Out:
# Collecting xgboostNote: you may need to restart the kernel to use updated packages.
#
#   Downloading xgboost-3.0.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\ksa\stenv\lib\site-packages (from xgboost) (2.3.1)
# Requirement already satisfied: scipy in c:\users\ksa\stenv\lib\site-packages (from xgboost) (1.16.0)
# Downloading xgboost-3.0.2-py3-none-win_amd64.whl (150.0 MB)
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#     --------------------------------------- 3.1/150.0 MB 45.8 MB/s eta 0:00:04
#    --- ------------------------------------ 12.6/150.0 MB 34.2 MB/s eta 0:00:05
#    ------- -------------------------------- 28.3/150.0 MB 47.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 43.0/150.0 MB 52.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 63.2/150.0 MB 61.9 MB/s eta 0:00:02
#    ------------------ --------------------- 70.0/150.0 MB 56.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 87.0/150.0 MB 60.3 MB/s eta 0:00:02
#    ------------------------ --------------- 90.4/150.0 MB 54.4 MB/s eta 0:00:02
#    ---------------------------- ---------- 109.3/150.0 MB 58.2 MB/s eta 0:00:01
#    -------------------------------- ------ 124.5/150.0 MB 59.3 MB/s eta 0:00:01
#    ------------------------------------- - 143.7/150.0 MB 62.0 MB/s eta 0:00:01
#    --------------------------------------  149.9/150.0 MB 63.0 MB/s eta 0:00:01
#    --------------------------------------- 150.0/150.0 MB 55.7 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.2

# %%
from xgboost import XGBClassifier
# Out:
# 0.9567059184812372 0.8783915747390243

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier(n_estimators=100,random_state=50)
xgb.fit(X_train,y_train)
scores=cross_validate(xgb,X_train,y_train,return_train_score=True,n_jobs=-1)
np.mean(scores['train_score']),np.mean(scores['test_score'])
# Out:
# (np.float64(0.9567059184812372), np.float64(0.8783915747390243))

# %%
# Out:
# Accuracy of the result is:
# 0.8746153846153846

# %%
pred=xgb.predict(X_test)
accuracy_score(pred,y_test)
# Out:
# 0.8746153846153846

# %% [markdown]
# ## - LightGBM
#
#
# 이름에서 알 수 있듯이 Light Gbm 은 컴퓨팅 워크로드를 '경량'으로 만들어 프로그램의 런타임을 더욱 향상시킵니다. 그러나 다른 알고리즘과 비교하여 동일하거나 더 높은 수준의 모델 성능을 계속 유지할 수 있습니다.
#
# - LightGBM의 경우에는 최대 손실값을 가지는 노드를 중심으로 계속해서 분할하는 '리프 중심 트리 분할(leaf-wise)' 방식을 사용한다.
# - 따라서 트리가 깊어지기위해 소요되는 시간과 메모리를 많이 절약할 수 있다.
# - 다만 적은 데이터에 대한 과적합(overfitting)이 발생하기 쉽다
#
#
# Light Gbm은 주로 두 가지 방법으로 런타임 속도와 정확도를 최적화합니다.
#
# 1. 연속 변수를 개별적으로 정렬하지 않고 다른 버킷으로 분할하는 히스토그램 기반 알고리즘을 채택합니다. 이것은 런타임을 많이 향상시킵니다.
# 2. 레벨 별 트리 성장 방식 (대부분의 다른 의사 결정 트리 기반 방식에서 사용) 대신 리프 방식 트리 성장 방식을 사용합니다. 아래 그림에서 알 수 있듯이 손실이 많은 잎 부분이 계속 성장 (베스트 핏 컷)하여 전체 손실 기능을 최소화합니다.

# %% [markdown]
# ![image.png](attachment:1bd21d5c-1789-4bd7-8d8d-33dc826c61ce.png)

# %% [markdown]
# ![image.png](attachment:9820833b-a251-468f-91b3-e059c53e20a4.png)

# %%
# %pip install lightgbm
# Out:
# Collecting lightgbmNote: you may need to restart the kernel to use updated packages.
#
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ksa\stenv\lib\site-packages (from lightgbm) (2.3.1)
# Requirement already satisfied: scipy in c:\users\ksa\stenv\lib\site-packages (from lightgbm) (1.16.0)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 12.7 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0

# %%
import lightgbm as lgb
# Out:
# [LightGBM] [Info] Number of positive: 3939, number of negative: 1258
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 380
# [LightGBM] [Info] Number of data points in the train set: 5197, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.757937 -> initscore=1.141404
# [LightGBM] [Info] Start training from score 1.141404
# [LightGBM] [Info] Number of positive: 3151, number of negative: 1007
# [LightGBM] [Info] Number of positive: 3151, number of negative: 1006
# [LightGBM] [Info] Number of positive: 3151, number of negative: 1006
# [LightGBM] [Info] Number of positive: 3151, number of negative: 1007
# [LightGBM] [Info] Number of positive: 3152, number of negative: 1006
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047603 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 373
# [LightGBM] [Info] Number of data points in the train set: 4158, number of used features: 3[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049587 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 372
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047969 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 370
#
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047861 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 371
# [LightGBM] [Info] Number of data points in the train set: 4157, number of used features: 3
# [LightGBM] [Info] Number of data points in the train set: 4157, number of used features: 3
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.062418 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 372
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.757816 -> initscore=1.140744
# [LightGBM] [Info] Number of data points in the train set: 4158, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.757999 -> initscore=1.141738
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.757999 -> initscore=1.141738
# [LightGBM] [Info] Number of data points in the train set: 4158, number of used features: 3
# [LightGBM] [Info] Start training from score 1.141738
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.758057 -> initscore=1.142055
# [LightGBM] [Info] Start training from score 1.141738
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.757816 -> initscore=1.140744[LightGBM] [Info] Start training from score 1.140744
#
# [LightGBM] [Info] Start training from score 1.142055
# [LightGBM] [Info] Start training from score 1.140744
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 0.935828414851749 0.8801251203079884
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/qkboo/micromamba/envs/DL_P312/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
import lightgbm as lgb
lgb=lgb.LGBMClassifier()
lgb.fit(X_train,y_train)
scores=cross_validate(lgb,X_train,y_train,return_train_score=True,n_jobs=-1)
print(np.mean(scores['train_score']),np.mean(scores['test_score']))

pred=lgb.predict(X_test)
accuracy_score(pred,y_test)
# Out:
# [LightGBM] [Info] Number of positive: 3939, number of negative: 1258
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000085 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 380
# [LightGBM] [Info] Number of data points in the train set: 5197, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.757937 -> initscore=1.141404
# [LightGBM] [Info] Start training from score 1.141404
# c:\Users\ksa\stenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 0.8730769230769231

# %% [markdown]
# ## - CatBoost
#
# CatBoost는 Categorical Boosting의 약자입니다. 범주 형 변수를 숫자로 변환 할 필요없이 자동으로 처리하는 뛰어난 기능이 있습니다.
#
# CatBoost는 5 가지 부스팅 알고리즘 중 가장 최근에 개발되었지만 Light Gbm에 매우 가깝습니다. 범주 형 변수가있을 때 더 잘 수행됩니다.

# %%
# %pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in c:\users\ksa\stenv\lib\site-packages (from catboost) (3.10.3)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\ksa\stenv\lib\site-packages (from catboost) (2.3.1)
# Requirement already satisfied: pandas>=0.24 in c:\users\ksa\stenv\lib\site-packages (from catboost) (2.3.1)
# Requirement already satisfied: scipy in c:\users\ksa\stenv\lib\site-packages (from catboost) (1.16.0)
# Collecting plotly (from catboost)
#   Downloading plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: six in c:\users\ksa\stenv\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ksa\stenv\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ksa\stenv\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ksa\stenv\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ksa\stenv\lib\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ksa\stenv\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ksa\stenv\lib\site-packages (from matplotlib->catboost) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ksa\stenv\lib\site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ksa\stenv\lib\site-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ksa\stenv\lib\site-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ksa\stenv\lib\site-packages (from matplotlib->catboost) (3.2.3)
# Collecting narwhals>=1.15.1 (from plotly->catboost)
#   Downloading narwhals-1.47.1-py3-none-any.whl.metadata (11 kB)
# Downloading catboost-1.2.8-cp312-cp312-win_amd64.whl (102.4 MB)
#    ---------------------------------------- 0.0/102.4 MB ? eta -:--:--
#    --- ------------------------------------ 7.9/102.4 MB 48.7 MB/s eta 0:00:02
#    ------ --------------------------------- 16.5/102.4 MB 43.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 27.3/102.4 MB 48.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 42.2/102.4 MB 51.7 MB/s eta 0:00:02
#    --------------------- ------------------ 54.0/102.4 MB 52.9 MB/s eta 0:00:01
#    -------------------------- ------------- 68.7/102.4 MB 55.4 MB/s eta 0:00:01
#    -------------------------------- ------- 83.6/102.4 MB 58.0 MB/s eta 0:00:01
#    ------------------------------------- -- 97.3/102.4 MB 58.6 MB/s eta 0:00:01
#    --------------------------------------  102.2/102.4 MB 58.3 MB/s eta 0:00:01
#    --------------------------------------- 102.4/102.4 MB 52.3 MB/s eta 0:00:00
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ----------------------------------- ---- 8.7/9.6 MB 41.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 39.9 MB/s eta 0:00:00
# Downloading narwhals-1.47.1-py3-none-any.whl (375 kB)
# Installing collected packages: narwhals, graphviz, plotly, catboost
#
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------- ----------------------------- 1/4 [graphviz]
#    ---------- ----------------------------- 1/4 [graphviz]
#    ---------- ----------------------------- 1/4 [graphviz]
#    ---------- ----------------------------- 1/4 [graphviz]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ---------------------------------------- 4/4 [catboost]
#
# Successfully installed catboost-1.2.8 graphviz-0.21 narwhals-1.47.1 plotly-6.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from catboost import CatBoostClassifier

# %%
from catboost import CatBoostClassifier

cbc=CatBoostClassifier()
cbc.fit(X_train,y_train)

scores=cross_validate(cbc,X_train,y_train,return_train_score=True,n_jobs=-1)
print(np.mean(scores['train_score']),np.mean(scores['test_score']))

pred=lgb.predict(X_test)
accuracy_score(pred,y_test)
# Out:
# Learning rate set to 0.020824
# 0:	learn: 0.6702036	total: 4.03ms	remaining: 4.02s
# 1:	learn: 0.6493385	total: 6.7ms	remaining: 3.34s
# 2:	learn: 0.6311795	total: 9.32ms	remaining: 3.1s
# 3:	learn: 0.6125310	total: 14ms	remaining: 3.5s
# 4:	learn: 0.5966572	total: 16.7ms	remaining: 3.33s
# 5:	learn: 0.5801129	total: 19ms	remaining: 3.15s
# 6:	learn: 0.5678174	total: 21.3ms	remaining: 3.02s
# 7:	learn: 0.5543454	total: 23.6ms	remaining: 2.93s
# 8:	learn: 0.5408798	total: 26.3ms	remaining: 2.89s
# 9:	learn: 0.5288259	total: 28.6ms	remaining: 2.83s
# 10:	learn: 0.5167912	total: 30.9ms	remaining: 2.78s
# 11:	learn: 0.5051166	total: 33.2ms	remaining: 2.73s
# 12:	learn: 0.4949977	total: 35.7ms	remaining: 2.71s
# 13:	learn: 0.4845963	total: 38.1ms	remaining: 2.68s
# 14:	learn: 0.4746651	total: 40.7ms	remaining: 2.67s
# 15:	learn: 0.4652639	total: 43.6ms	remaining: 2.68s
# 16:	learn: 0.4570253	total: 46.9ms	remaining: 2.71s
# 17:	learn: 0.4496896	total: 49.5ms	remaining: 2.7s
# 18:	learn: 0.4430102	total: 52.4ms	remaining: 2.7s
# 19:	learn: 0.4357541	total: 57ms	remaining: 2.79s
# 20:	learn: 0.4295431	total: 60.1ms	remaining: 2.8s
# 21:	learn: 0.4239757	total: 62.8ms	remaining: 2.79s
# 22:	learn: 0.4187599	total: 65.1ms	remaining: 2.76s
# 23:	learn: 0.4131913	total: 67.4ms	remaining: 2.74s
# 24:	learn: 0.4074332	total: 70.1ms	remaining: 2.73s
# 25:	learn: 0.4019724	total: 72.8ms	remaining: 2.73s
# 26:	learn: 0.3969698	total: 76.8ms	remaining: 2.77s
# 27:	learn: 0.3919390	total: 79.8ms	remaining: 2.77s
# 28:	learn: 0.3883439	total: 82.4ms	remaining: 2.76s
# 29:	learn: 0.3842497	total: 84.9ms	remaining: 2.74s
# 30:	learn: 0.3798187	total: 87.5ms	remaining: 2.74s
# 31:	learn: 0.3763554	total: 90.3ms	remaining: 2.73s
# 32:	learn: 0.3729233	total: 93.3ms	remaining: 2.73s
# 33:	learn: 0.3698240	total: 95.7ms	remaining: 2.72s
# 34:	learn: 0.3666823	total: 98.5ms	remaining: 2.72s
# 35:	learn: 0.3632026	total: 103ms	remaining: 2.76s
# 36:	learn: 0.3602097	total: 107ms	remaining: 2.78s
# 37:	learn: 0.3573584	total: 110ms	remaining: 2.78s
# 38:	learn: 0.3546944	total: 112ms	remaining: 2.77s
# 39:	learn: 0.3518974	total: 115ms	remaining: 2.76s
# 40:	learn: 0.3486784	total: 118ms	remaining: 2.77s
# 41:	learn: 0.3460093	total: 121ms	remaining: 2.76s
# 42:	learn: 0.3441377	total: 124ms	remaining: 2.75s
# 43:	learn: 0.3421495	total: 126ms	remaining: 2.74s
# 44:	learn: 0.3396320	total: 129ms	remaining: 2.73s
# 45:	learn: 0.3376110	total: 131ms	remaining: 2.72s
# 46:	learn: 0.3355296	total: 135ms	remaining: 2.73s
# 47:	learn: 0.3335480	total: 137ms	remaining: 2.72s
# 48:	learn: 0.3317584	total: 140ms	remaining: 2.71s
# 49:	learn: 0.3304003	total: 142ms	remaining: 2.7s
# 50:	learn: 0.3288020	total: 145ms	remaining: 2.69s
# 51:	learn: 0.3275772	total: 148ms	remaining: 2.69s
# 52:	learn: 0.3258634	total: 150ms	remaining: 2.68s
# 53:	learn: 0.3244038	total: 153ms	remaining: 2.67s
# 54:	learn: 0.3231916	total: 155ms	remaining: 2.66s
# 55:	learn: 0.3221204	total: 157ms	remaining: 2.65s
# 56:	learn: 0.3208688	total: 160ms	remaining: 2.64s
# 57:	learn: 0.3197740	total: 162ms	remaining: 2.64s
# 58:	learn: 0.3185421	total: 165ms	remaining: 2.63s
# 59:	learn: 0.3174384	total: 168ms	remaining: 2.63s
# 60:	learn: 0.3163130	total: 171ms	remaining: 2.63s
# 61:	learn: 0.3153879	total: 173ms	remaining: 2.62s
# 62:	learn: 0.3144187	total: 175ms	remaining: 2.61s
# 63:	learn: 0.3131042	total: 178ms	remaining: 2.6s
# 64:	learn: 0.3124286	total: 180ms	remaining: 2.6s
# 65:	learn: 0.3112695	total: 183ms	remaining: 2.59s
# 66:	learn: 0.3107841	total: 187ms	remaining: 2.6s
# 67:	learn: 0.3100548	total: 189ms	remaining: 2.59s
# 68:	learn: 0.3090925	total: 191ms	remaining: 2.58s
# 69:	learn: 0.3081265	total: 194ms	remaining: 2.57s
# 70:	learn: 0.3073903	total: 198ms	remaining: 2.58s
# 71:	learn: 0.3067855	total: 203ms	remaining: 2.62s
# 72:	learn: 0.3060112	total: 207ms	remaining: 2.63s
# 73:	learn: 0.3049890	total: 210ms	remaining: 2.63s
# 74:	learn: 0.3042249	total: 213ms	remaining: 2.62s
# 75:	learn: 0.3033473	total: 216ms	remaining: 2.63s
# 76:	learn: 0.3029862	total: 220ms	remaining: 2.63s
# 77:	learn: 0.3023343	total: 222ms	remaining: 2.63s
# 78:	learn: 0.3015626	total: 225ms	remaining: 2.63s
# 79:	learn: 0.3009703	total: 228ms	remaining: 2.62s
# 80:	learn: 0.3006171	total: 231ms	remaining: 2.62s
# 81:	learn: 0.2998915	total: 234ms	remaining: 2.62s
# 82:	learn: 0.2993946	total: 237ms	remaining: 2.62s
# 83:	learn: 0.2988772	total: 240ms	remaining: 2.61s
# 84:	learn: 0.2983883	total: 242ms	remaining: 2.61s
# 85:	learn: 0.2978945	total: 245ms	remaining: 2.6s
# 86:	learn: 0.2974205	total: 247ms	remaining: 2.59s
# 87:	learn: 0.2969412	total: 250ms	remaining: 2.59s
# 88:	learn: 0.2963906	total: 252ms	remaining: 2.58s
# 89:	learn: 0.2958895	total: 255ms	remaining: 2.58s
# 90:	learn: 0.2953404	total: 258ms	remaining: 2.57s
# 91:	learn: 0.2949303	total: 260ms	remaining: 2.57s
# 92:	learn: 0.2945039	total: 262ms	remaining: 2.56s
# 93:	learn: 0.2941612	total: 265ms	remaining: 2.55s
# 94:	learn: 0.2937823	total: 267ms	remaining: 2.55s
# 95:	learn: 0.2933706	total: 271ms	remaining: 2.55s
# 96:	learn: 0.2931262	total: 273ms	remaining: 2.54s
# 97:	learn: 0.2927481	total: 275ms	remaining: 2.53s
# 98:	learn: 0.2924555	total: 278ms	remaining: 2.53s
# 99:	learn: 0.2921736	total: 282ms	remaining: 2.54s
# 100:	learn: 0.2917733	total: 284ms	remaining: 2.53s
# 101:	learn: 0.2913457	total: 287ms	remaining: 2.53s
# 102:	learn: 0.2911256	total: 290ms	remaining: 2.52s
# 103:	learn: 0.2907068	total: 292ms	remaining: 2.52s
# 104:	learn: 0.2904683	total: 295ms	remaining: 2.51s
# 105:	learn: 0.2901017	total: 297ms	remaining: 2.51s
# 106:	learn: 0.2897760	total: 301ms	remaining: 2.51s
# 107:	learn: 0.2894662	total: 304ms	remaining: 2.51s
# 108:	learn: 0.2892190	total: 306ms	remaining: 2.5s
# 109:	learn: 0.2888329	total: 308ms	remaining: 2.49s
# 110:	learn: 0.2886188	total: 311ms	remaining: 2.49s
# 111:	learn: 0.2883651	total: 313ms	remaining: 2.48s
# 112:	learn: 0.2881411	total: 316ms	remaining: 2.48s
# 113:	learn: 0.2879065	total: 319ms	remaining: 2.48s
# 114:	learn: 0.2875841	total: 322ms	remaining: 2.48s
# 115:	learn: 0.2872412	total: 325ms	remaining: 2.47s
# 116:	learn: 0.2870391	total: 327ms	remaining: 2.47s
# 117:	learn: 0.2868020	total: 330ms	remaining: 2.47s
# 118:	learn: 0.2865999	total: 332ms	remaining: 2.46s
# 119:	learn: 0.2863052	total: 335ms	remaining: 2.45s
# 120:	learn: 0.2860295	total: 337ms	remaining: 2.45s
# 121:	learn: 0.2857162	total: 339ms	remaining: 2.44s
# 122:	learn: 0.2855581	total: 342ms	remaining: 2.44s
# 123:	learn: 0.2853505	total: 344ms	remaining: 2.43s
# 124:	learn: 0.2851765	total: 347ms	remaining: 2.43s
# 125:	learn: 0.2849950	total: 349ms	remaining: 2.42s
# 126:	learn: 0.2847602	total: 351ms	remaining: 2.42s
# 127:	learn: 0.2845833	total: 354ms	remaining: 2.41s
# 128:	learn: 0.2843219	total: 356ms	remaining: 2.4s
# 129:	learn: 0.2840880	total: 358ms	remaining: 2.4s
# 130:	learn: 0.2837694	total: 361ms	remaining: 2.39s
# 131:	learn: 0.2836418	total: 363ms	remaining: 2.39s
# 132:	learn: 0.2833867	total: 365ms	remaining: 2.38s
# 133:	learn: 0.2831056	total: 368ms	remaining: 2.38s
# 134:	learn: 0.2828800	total: 370ms	remaining: 2.37s
# 135:	learn: 0.2827819	total: 372ms	remaining: 2.37s
# 136:	learn: 0.2826050	total: 375ms	remaining: 2.36s
# 137:	learn: 0.2823774	total: 377ms	remaining: 2.35s
# 138:	learn: 0.2822204	total: 379ms	remaining: 2.35s
# 139:	learn: 0.2821011	total: 382ms	remaining: 2.34s
# 140:	learn: 0.2818902	total: 384ms	remaining: 2.34s
# 141:	learn: 0.2817638	total: 387ms	remaining: 2.33s
# 142:	learn: 0.2816142	total: 389ms	remaining: 2.33s
# 143:	learn: 0.2814119	total: 392ms	remaining: 2.33s
# 144:	learn: 0.2812269	total: 394ms	remaining: 2.32s
# 145:	learn: 0.2809729	total: 397ms	remaining: 2.32s
# 146:	learn: 0.2808711	total: 399ms	remaining: 2.31s
# 147:	learn: 0.2807763	total: 402ms	remaining: 2.31s
# 148:	learn: 0.2805900	total: 407ms	remaining: 2.32s
# 149:	learn: 0.2804530	total: 409ms	remaining: 2.32s
# 150:	learn: 0.2802324	total: 411ms	remaining: 2.31s
# 151:	learn: 0.2801175	total: 414ms	remaining: 2.31s
# 152:	learn: 0.2800334	total: 416ms	remaining: 2.3s
# 153:	learn: 0.2798925	total: 419ms	remaining: 2.3s
# 154:	learn: 0.2798080	total: 421ms	remaining: 2.3s
# 155:	learn: 0.2795689	total: 424ms	remaining: 2.3s
# 156:	learn: 0.2793105	total: 427ms	remaining: 2.29s
# 157:	learn: 0.2791181	total: 430ms	remaining: 2.29s
# 158:	learn: 0.2789097	total: 433ms	remaining: 2.29s
# 159:	learn: 0.2787703	total: 435ms	remaining: 2.29s
# 160:	learn: 0.2786737	total: 438ms	remaining: 2.28s
# 161:	learn: 0.2784896	total: 441ms	remaining: 2.28s
# 162:	learn: 0.2783255	total: 443ms	remaining: 2.27s
# 163:	learn: 0.2781022	total: 445ms	remaining: 2.27s
# 164:	learn: 0.2779749	total: 448ms	remaining: 2.27s
# 165:	learn: 0.2778519	total: 451ms	remaining: 2.26s
# 166:	learn: 0.2777401	total: 453ms	remaining: 2.26s
# 167:	learn: 0.2776658	total: 456ms	remaining: 2.25s
# 168:	learn: 0.2776160	total: 457ms	remaining: 2.25s
# 169:	learn: 0.2773848	total: 459ms	remaining: 2.24s
# 170:	learn: 0.2773117	total: 462ms	remaining: 2.24s
# 171:	learn: 0.2771481	total: 464ms	remaining: 2.23s
# 172:	learn: 0.2769841	total: 467ms	remaining: 2.23s
# 173:	learn: 0.2768110	total: 469ms	remaining: 2.23s
# 174:	learn: 0.2766654	total: 472ms	remaining: 2.22s
# 175:	learn: 0.2765015	total: 474ms	remaining: 2.22s
# 176:	learn: 0.2763960	total: 477ms	remaining: 2.22s
# 177:	learn: 0.2762419	total: 479ms	remaining: 2.21s
# 178:	learn: 0.2761654	total: 482ms	remaining: 2.21s
# 179:	learn: 0.2760150	total: 484ms	remaining: 2.21s
# 180:	learn: 0.2759200	total: 486ms	remaining: 2.2s
# 181:	learn: 0.2758221	total: 489ms	remaining: 2.2s
# 182:	learn: 0.2756708	total: 491ms	remaining: 2.19s
# 183:	learn: 0.2755143	total: 494ms	remaining: 2.19s
# 184:	learn: 0.2754026	total: 496ms	remaining: 2.18s
# 185:	learn: 0.2752392	total: 498ms	remaining: 2.18s
# 186:	learn: 0.2751030	total: 501ms	remaining: 2.18s
# 187:	learn: 0.2749683	total: 503ms	remaining: 2.17s
# 188:	learn: 0.2748799	total: 506ms	remaining: 2.17s
# 189:	learn: 0.2746375	total: 508ms	remaining: 2.17s
# 190:	learn: 0.2745488	total: 510ms	remaining: 2.16s
# 191:	learn: 0.2744267	total: 513ms	remaining: 2.16s
# 192:	learn: 0.2743381	total: 515ms	remaining: 2.15s
# 193:	learn: 0.2741218	total: 517ms	remaining: 2.15s
# 194:	learn: 0.2740409	total: 520ms	remaining: 2.15s
# 195:	learn: 0.2739718	total: 522ms	remaining: 2.14s
# 196:	learn: 0.2738787	total: 524ms	remaining: 2.14s
# 197:	learn: 0.2738384	total: 527ms	remaining: 2.13s
# 198:	learn: 0.2737448	total: 529ms	remaining: 2.13s
# 199:	learn: 0.2736985	total: 531ms	remaining: 2.13s
# 200:	learn: 0.2736377	total: 534ms	remaining: 2.12s
# 201:	learn: 0.2734697	total: 537ms	remaining: 2.12s
# 202:	learn: 0.2733958	total: 540ms	remaining: 2.12s
# 203:	learn: 0.2732896	total: 542ms	remaining: 2.12s
# 204:	learn: 0.2732043	total: 544ms	remaining: 2.11s
# 205:	learn: 0.2730658	total: 547ms	remaining: 2.11s
# 206:	learn: 0.2729979	total: 549ms	remaining: 2.1s
# 207:	learn: 0.2728578	total: 552ms	remaining: 2.1s
# 208:	learn: 0.2727258	total: 554ms	remaining: 2.1s
# 209:	learn: 0.2726717	total: 557ms	remaining: 2.09s
# 210:	learn: 0.2725252	total: 559ms	remaining: 2.09s
# 211:	learn: 0.2724353	total: 561ms	remaining: 2.08s
# 212:	learn: 0.2723165	total: 564ms	remaining: 2.08s
# 213:	learn: 0.2722209	total: 566ms	remaining: 2.08s
# 214:	learn: 0.2721197	total: 569ms	remaining: 2.08s
# 215:	learn: 0.2720197	total: 571ms	remaining: 2.07s
# 216:	learn: 0.2719304	total: 573ms	remaining: 2.07s
# 217:	learn: 0.2717382	total: 576ms	remaining: 2.06s
# 218:	learn: 0.2716906	total: 579ms	remaining: 2.06s
# 219:	learn: 0.2716100	total: 581ms	remaining: 2.06s
# 220:	learn: 0.2714763	total: 583ms	remaining: 2.06s
# 221:	learn: 0.2713632	total: 586ms	remaining: 2.05s
# 222:	learn: 0.2712670	total: 588ms	remaining: 2.05s
# 223:	learn: 0.2711927	total: 591ms	remaining: 2.04s
# 224:	learn: 0.2710401	total: 593ms	remaining: 2.04s
# 225:	learn: 0.2709966	total: 596ms	remaining: 2.04s
# 226:	learn: 0.2708439	total: 598ms	remaining: 2.04s
# 227:	learn: 0.2707648	total: 600ms	remaining: 2.03s
# 228:	learn: 0.2706833	total: 603ms	remaining: 2.03s
# 229:	learn: 0.2705646	total: 605ms	remaining: 2.03s
# 230:	learn: 0.2704332	total: 608ms	remaining: 2.02s
# 231:	learn: 0.2702907	total: 612ms	remaining: 2.03s
# 232:	learn: 0.2701843	total: 616ms	remaining: 2.03s
# 233:	learn: 0.2700650	total: 618ms	remaining: 2.02s
# 234:	learn: 0.2699436	total: 620ms	remaining: 2.02s
# 235:	learn: 0.2698035	total: 623ms	remaining: 2.02s
# 236:	learn: 0.2697095	total: 626ms	remaining: 2.02s
# 237:	learn: 0.2696151	total: 630ms	remaining: 2.02s
# 238:	learn: 0.2695457	total: 634ms	remaining: 2.02s
# 239:	learn: 0.2694677	total: 636ms	remaining: 2.01s
# 240:	learn: 0.2693953	total: 638ms	remaining: 2.01s
# 241:	learn: 0.2693091	total: 641ms	remaining: 2.01s
# 242:	learn: 0.2692148	total: 644ms	remaining: 2s
# 243:	learn: 0.2691900	total: 646ms	remaining: 2s
# 244:	learn: 0.2690536	total: 649ms	remaining: 2s
# 245:	learn: 0.2689616	total: 651ms	remaining: 2s
# 246:	learn: 0.2688752	total: 653ms	remaining: 1.99s
# 247:	learn: 0.2688380	total: 656ms	remaining: 1.99s
# 248:	learn: 0.2687407	total: 658ms	remaining: 1.99s
# 249:	learn: 0.2687126	total: 661ms	remaining: 1.98s
# 250:	learn: 0.2686391	total: 663ms	remaining: 1.98s
# 251:	learn: 0.2685551	total: 666ms	remaining: 1.98s
# 252:	learn: 0.2685062	total: 669ms	remaining: 1.97s
# 253:	learn: 0.2684259	total: 671ms	remaining: 1.97s
# 254:	learn: 0.2683552	total: 673ms	remaining: 1.97s
# 255:	learn: 0.2682581	total: 676ms	remaining: 1.96s
# 256:	learn: 0.2681392	total: 679ms	remaining: 1.96s
# 257:	learn: 0.2680406	total: 681ms	remaining: 1.96s
# 258:	learn: 0.2679278	total: 684ms	remaining: 1.96s
# 259:	learn: 0.2678596	total: 686ms	remaining: 1.95s
# 260:	learn: 0.2677987	total: 688ms	remaining: 1.95s
# 261:	learn: 0.2677568	total: 691ms	remaining: 1.95s
# 262:	learn: 0.2677225	total: 693ms	remaining: 1.94s
# 263:	learn: 0.2676598	total: 697ms	remaining: 1.94s
# 264:	learn: 0.2675786	total: 700ms	remaining: 1.94s
# 265:	learn: 0.2675039	total: 703ms	remaining: 1.94s
# 266:	learn: 0.2674530	total: 705ms	remaining: 1.94s
# 267:	learn: 0.2674026	total: 708ms	remaining: 1.93s
# 268:	learn: 0.2673214	total: 711ms	remaining: 1.93s
# 269:	learn: 0.2672642	total: 714ms	remaining: 1.93s
# 270:	learn: 0.2671732	total: 717ms	remaining: 1.93s
# 271:	learn: 0.2671035	total: 719ms	remaining: 1.92s
# 272:	learn: 0.2670056	total: 721ms	remaining: 1.92s
# 273:	learn: 0.2668854	total: 724ms	remaining: 1.92s
# 274:	learn: 0.2668443	total: 728ms	remaining: 1.92s
# 275:	learn: 0.2667698	total: 731ms	remaining: 1.92s
# 276:	learn: 0.2667305	total: 734ms	remaining: 1.92s
# 277:	learn: 0.2666749	total: 736ms	remaining: 1.91s
# 278:	learn: 0.2665966	total: 739ms	remaining: 1.91s
# 279:	learn: 0.2664887	total: 741ms	remaining: 1.91s
# 280:	learn: 0.2663882	total: 744ms	remaining: 1.9s
# 281:	learn: 0.2663602	total: 746ms	remaining: 1.9s
# 282:	learn: 0.2662616	total: 749ms	remaining: 1.9s
# 283:	learn: 0.2661905	total: 752ms	remaining: 1.89s
# 284:	learn: 0.2661201	total: 754ms	remaining: 1.89s
# 285:	learn: 0.2660771	total: 756ms	remaining: 1.89s
# 286:	learn: 0.2660279	total: 759ms	remaining: 1.89s
# 287:	learn: 0.2659824	total: 761ms	remaining: 1.88s
# 288:	learn: 0.2659172	total: 764ms	remaining: 1.88s
# 289:	learn: 0.2658369	total: 766ms	remaining: 1.88s
# 290:	learn: 0.2657168	total: 769ms	remaining: 1.87s
# 291:	learn: 0.2656432	total: 772ms	remaining: 1.87s
# 292:	learn: 0.2654911	total: 776ms	remaining: 1.87s
# 293:	learn: 0.2654058	total: 778ms	remaining: 1.87s
# 294:	learn: 0.2653513	total: 780ms	remaining: 1.86s
# 295:	learn: 0.2652671	total: 783ms	remaining: 1.86s
# 296:	learn: 0.2650718	total: 785ms	remaining: 1.86s
# 297:	learn: 0.2650260	total: 789ms	remaining: 1.86s
# 298:	learn: 0.2649436	total: 793ms	remaining: 1.86s
# 299:	learn: 0.2649010	total: 796ms	remaining: 1.86s
# 300:	learn: 0.2648080	total: 799ms	remaining: 1.85s
# 301:	learn: 0.2646751	total: 802ms	remaining: 1.85s
# 302:	learn: 0.2645974	total: 804ms	remaining: 1.85s
# 303:	learn: 0.2645335	total: 808ms	remaining: 1.85s
# 304:	learn: 0.2643860	total: 810ms	remaining: 1.84s
# 305:	learn: 0.2643720	total: 812ms	remaining: 1.84s
# 306:	learn: 0.2643183	total: 815ms	remaining: 1.84s
# 307:	learn: 0.2642176	total: 818ms	remaining: 1.84s
# 308:	learn: 0.2641502	total: 821ms	remaining: 1.83s
# 309:	learn: 0.2639868	total: 824ms	remaining: 1.83s
# 310:	learn: 0.2639361	total: 827ms	remaining: 1.83s
# 311:	learn: 0.2638677	total: 830ms	remaining: 1.83s
# 312:	learn: 0.2638301	total: 832ms	remaining: 1.83s
# 313:	learn: 0.2637956	total: 837ms	remaining: 1.83s
# 314:	learn: 0.2636655	total: 840ms	remaining: 1.83s
# 315:	learn: 0.2635258	total: 844ms	remaining: 1.82s
# 316:	learn: 0.2634855	total: 846ms	remaining: 1.82s
# 317:	learn: 0.2633771	total: 849ms	remaining: 1.82s
# 318:	learn: 0.2632976	total: 853ms	remaining: 1.82s
# 319:	learn: 0.2632218	total: 857ms	remaining: 1.82s
# 320:	learn: 0.2631438	total: 860ms	remaining: 1.82s
# 321:	learn: 0.2631236	total: 862ms	remaining: 1.81s
# 322:	learn: 0.2630168	total: 868ms	remaining: 1.82s
# 323:	learn: 0.2628660	total: 872ms	remaining: 1.82s
# 324:	learn: 0.2628476	total: 875ms	remaining: 1.82s
# 325:	learn: 0.2627959	total: 877ms	remaining: 1.81s
# 326:	learn: 0.2627034	total: 882ms	remaining: 1.81s
# 327:	learn: 0.2626898	total: 886ms	remaining: 1.81s
# 328:	learn: 0.2626338	total: 890ms	remaining: 1.81s
# 329:	learn: 0.2625700	total: 893ms	remaining: 1.81s
# 330:	learn: 0.2625077	total: 896ms	remaining: 1.81s
# 331:	learn: 0.2624269	total: 900ms	remaining: 1.81s
# 332:	learn: 0.2623886	total: 903ms	remaining: 1.81s
# 333:	learn: 0.2623026	total: 905ms	remaining: 1.8s
# 334:	learn: 0.2622469	total: 908ms	remaining: 1.8s
# 335:	learn: 0.2621212	total: 914ms	remaining: 1.81s
# 336:	learn: 0.2620381	total: 919ms	remaining: 1.81s
# 337:	learn: 0.2619955	total: 921ms	remaining: 1.8s
# 338:	learn: 0.2619758	total: 924ms	remaining: 1.8s
# 339:	learn: 0.2618694	total: 928ms	remaining: 1.8s
# 340:	learn: 0.2616781	total: 932ms	remaining: 1.8s
# 341:	learn: 0.2615196	total: 935ms	remaining: 1.8s
# 342:	learn: 0.2614197	total: 937ms	remaining: 1.79s
# 343:	learn: 0.2613290	total: 941ms	remaining: 1.79s
# 344:	learn: 0.2612483	total: 947ms	remaining: 1.8s
# 345:	learn: 0.2611955	total: 950ms	remaining: 1.79s
# 346:	learn: 0.2611222	total: 953ms	remaining: 1.79s
# 347:	learn: 0.2610986	total: 957ms	remaining: 1.79s
# 348:	learn: 0.2610697	total: 960ms	remaining: 1.79s
# 349:	learn: 0.2610433	total: 965ms	remaining: 1.79s
# 350:	learn: 0.2609621	total: 969ms	remaining: 1.79s
# 351:	learn: 0.2608891	total: 972ms	remaining: 1.79s
# 352:	learn: 0.2608642	total: 977ms	remaining: 1.79s
# 353:	learn: 0.2607980	total: 980ms	remaining: 1.79s
# 354:	learn: 0.2607121	total: 983ms	remaining: 1.78s
# 355:	learn: 0.2606101	total: 985ms	remaining: 1.78s
# 356:	learn: 0.2605710	total: 989ms	remaining: 1.78s
# 357:	learn: 0.2604742	total: 994ms	remaining: 1.78s
# 358:	learn: 0.2604081	total: 996ms	remaining: 1.78s
# 359:	learn: 0.2603452	total: 999ms	remaining: 1.77s
# 360:	learn: 0.2602516	total: 1s	remaining: 1.77s
# 361:	learn: 0.2601705	total: 1s	remaining: 1.77s
# 362:	learn: 0.2600491	total: 1.01s	remaining: 1.77s
# 363:	learn: 0.2600316	total: 1.01s	remaining: 1.77s
# 364:	learn: 0.2599658	total: 1.01s	remaining: 1.76s
# 365:	learn: 0.2599369	total: 1.02s	remaining: 1.76s
# 366:	learn: 0.2598975	total: 1.02s	remaining: 1.76s
# 367:	learn: 0.2598759	total: 1.02s	remaining: 1.76s
# 368:	learn: 0.2598687	total: 1.03s	remaining: 1.75s
# 369:	learn: 0.2597553	total: 1.03s	remaining: 1.75s
# 370:	learn: 0.2596955	total: 1.03s	remaining: 1.75s
# 371:	learn: 0.2596517	total: 1.03s	remaining: 1.75s
# 372:	learn: 0.2595528	total: 1.04s	remaining: 1.75s
# 373:	learn: 0.2594674	total: 1.04s	remaining: 1.74s
# 374:	learn: 0.2594113	total: 1.04s	remaining: 1.74s
# 375:	learn: 0.2593588	total: 1.05s	remaining: 1.74s
# 376:	learn: 0.2592889	total: 1.05s	remaining: 1.74s
# 377:	learn: 0.2591288	total: 1.05s	remaining: 1.73s
# 378:	learn: 0.2589991	total: 1.06s	remaining: 1.73s
# 379:	learn: 0.2589531	total: 1.06s	remaining: 1.73s
# 380:	learn: 0.2589322	total: 1.06s	remaining: 1.73s
# 381:	learn: 0.2588711	total: 1.06s	remaining: 1.72s
# 382:	learn: 0.2587999	total: 1.07s	remaining: 1.72s
# 383:	learn: 0.2586571	total: 1.07s	remaining: 1.72s
# 384:	learn: 0.2586442	total: 1.07s	remaining: 1.72s
# 385:	learn: 0.2584787	total: 1.08s	remaining: 1.71s
# 386:	learn: 0.2584304	total: 1.08s	remaining: 1.71s
# 387:	learn: 0.2583628	total: 1.08s	remaining: 1.71s
# 388:	learn: 0.2582757	total: 1.09s	remaining: 1.71s
# 389:	learn: 0.2581742	total: 1.09s	remaining: 1.7s
# 390:	learn: 0.2580655	total: 1.09s	remaining: 1.7s
# 391:	learn: 0.2580038	total: 1.09s	remaining: 1.7s
# 392:	learn: 0.2578622	total: 1.1s	remaining: 1.7s
# 393:	learn: 0.2578177	total: 1.1s	remaining: 1.69s
# 394:	learn: 0.2576857	total: 1.1s	remaining: 1.69s
# 395:	learn: 0.2575584	total: 1.11s	remaining: 1.69s
# 396:	learn: 0.2574765	total: 1.11s	remaining: 1.69s
# 397:	learn: 0.2574029	total: 1.11s	remaining: 1.68s
# 398:	learn: 0.2573506	total: 1.11s	remaining: 1.68s
# 399:	learn: 0.2572774	total: 1.12s	remaining: 1.68s
# 400:	learn: 0.2572264	total: 1.12s	remaining: 1.67s
# 401:	learn: 0.2570999	total: 1.12s	remaining: 1.67s
# 402:	learn: 0.2570636	total: 1.13s	remaining: 1.67s
# 403:	learn: 0.2568822	total: 1.13s	remaining: 1.66s
# 404:	learn: 0.2568642	total: 1.13s	remaining: 1.66s
# 405:	learn: 0.2567802	total: 1.13s	remaining: 1.66s
# 406:	learn: 0.2566602	total: 1.14s	remaining: 1.66s
# 407:	learn: 0.2566137	total: 1.14s	remaining: 1.65s
# 408:	learn: 0.2565117	total: 1.14s	remaining: 1.65s
# 409:	learn: 0.2564202	total: 1.14s	remaining: 1.65s
# 410:	learn: 0.2563471	total: 1.15s	remaining: 1.65s
# 411:	learn: 0.2563309	total: 1.15s	remaining: 1.64s
# 412:	learn: 0.2561966	total: 1.15s	remaining: 1.64s
# 413:	learn: 0.2560932	total: 1.16s	remaining: 1.64s
# 414:	learn: 0.2559987	total: 1.16s	remaining: 1.63s
# 415:	learn: 0.2559237	total: 1.16s	remaining: 1.63s
# 416:	learn: 0.2558809	total: 1.16s	remaining: 1.63s
# 417:	learn: 0.2558084	total: 1.17s	remaining: 1.63s
# 418:	learn: 0.2556759	total: 1.17s	remaining: 1.62s
# 419:	learn: 0.2556617	total: 1.17s	remaining: 1.62s
# 420:	learn: 0.2555518	total: 1.18s	remaining: 1.62s
# 421:	learn: 0.2554055	total: 1.18s	remaining: 1.61s
# 422:	learn: 0.2552798	total: 1.18s	remaining: 1.61s
# 423:	learn: 0.2552064	total: 1.18s	remaining: 1.61s
# 424:	learn: 0.2551071	total: 1.19s	remaining: 1.6s
# 425:	learn: 0.2549792	total: 1.19s	remaining: 1.6s
# 426:	learn: 0.2549239	total: 1.19s	remaining: 1.6s
# 427:	learn: 0.2548065	total: 1.19s	remaining: 1.59s
# 428:	learn: 0.2547836	total: 1.2s	remaining: 1.59s
# 429:	learn: 0.2547012	total: 1.2s	remaining: 1.59s
# 430:	learn: 0.2546237	total: 1.2s	remaining: 1.58s
# 431:	learn: 0.2545459	total: 1.2s	remaining: 1.58s
# 432:	learn: 0.2544703	total: 1.21s	remaining: 1.58s
# 433:	learn: 0.2544003	total: 1.21s	remaining: 1.58s
# 434:	learn: 0.2543718	total: 1.21s	remaining: 1.58s
# 435:	learn: 0.2543338	total: 1.22s	remaining: 1.57s
# 436:	learn: 0.2541874	total: 1.22s	remaining: 1.57s
# 437:	learn: 0.2541081	total: 1.22s	remaining: 1.57s
# 438:	learn: 0.2539707	total: 1.22s	remaining: 1.56s
# 439:	learn: 0.2538501	total: 1.23s	remaining: 1.56s
# 440:	learn: 0.2537710	total: 1.23s	remaining: 1.56s
# 441:	learn: 0.2536715	total: 1.23s	remaining: 1.56s
# 442:	learn: 0.2536304	total: 1.24s	remaining: 1.55s
# 443:	learn: 0.2535750	total: 1.24s	remaining: 1.55s
# 444:	learn: 0.2535026	total: 1.24s	remaining: 1.55s
# 445:	learn: 0.2534038	total: 1.24s	remaining: 1.55s
# 446:	learn: 0.2533044	total: 1.25s	remaining: 1.54s
# 447:	learn: 0.2532466	total: 1.25s	remaining: 1.54s
# 448:	learn: 0.2531018	total: 1.25s	remaining: 1.54s
# 449:	learn: 0.2530453	total: 1.25s	remaining: 1.53s
# 450:	learn: 0.2529234	total: 1.26s	remaining: 1.53s
# 451:	learn: 0.2528220	total: 1.26s	remaining: 1.53s
# 452:	learn: 0.2527913	total: 1.26s	remaining: 1.52s
# 453:	learn: 0.2527260	total: 1.26s	remaining: 1.52s
# 454:	learn: 0.2526650	total: 1.27s	remaining: 1.52s
# 455:	learn: 0.2525429	total: 1.27s	remaining: 1.51s
# 456:	learn: 0.2524892	total: 1.27s	remaining: 1.51s
# 457:	learn: 0.2523862	total: 1.27s	remaining: 1.51s
# 458:	learn: 0.2522853	total: 1.28s	remaining: 1.51s
# 459:	learn: 0.2521291	total: 1.28s	remaining: 1.5s
# 460:	learn: 0.2520474	total: 1.28s	remaining: 1.5s
# 461:	learn: 0.2520380	total: 1.28s	remaining: 1.5s
# 462:	learn: 0.2519867	total: 1.29s	remaining: 1.49s
# 463:	learn: 0.2519551	total: 1.29s	remaining: 1.49s
# 464:	learn: 0.2518582	total: 1.29s	remaining: 1.49s
# 465:	learn: 0.2518135	total: 1.29s	remaining: 1.48s
# 466:	learn: 0.2517963	total: 1.3s	remaining: 1.48s
# 467:	learn: 0.2516999	total: 1.3s	remaining: 1.48s
# 468:	learn: 0.2516572	total: 1.3s	remaining: 1.48s
# 469:	learn: 0.2515865	total: 1.3s	remaining: 1.47s
# 470:	learn: 0.2514908	total: 1.31s	remaining: 1.47s
# 471:	learn: 0.2514004	total: 1.31s	remaining: 1.47s
# 472:	learn: 0.2513446	total: 1.31s	remaining: 1.46s
# 473:	learn: 0.2512390	total: 1.32s	remaining: 1.46s
# 474:	learn: 0.2511392	total: 1.32s	remaining: 1.46s
# 475:	learn: 0.2509930	total: 1.32s	remaining: 1.45s
# 476:	learn: 0.2509209	total: 1.32s	remaining: 1.45s
# 477:	learn: 0.2508210	total: 1.33s	remaining: 1.45s
# 478:	learn: 0.2507529	total: 1.33s	remaining: 1.45s
# 479:	learn: 0.2505994	total: 1.33s	remaining: 1.44s
# 480:	learn: 0.2505423	total: 1.33s	remaining: 1.44s
# 481:	learn: 0.2504919	total: 1.34s	remaining: 1.44s
# 482:	learn: 0.2504094	total: 1.34s	remaining: 1.44s
# 483:	learn: 0.2504055	total: 1.34s	remaining: 1.43s
# 484:	learn: 0.2503150	total: 1.35s	remaining: 1.43s
# 485:	learn: 0.2502900	total: 1.35s	remaining: 1.43s
# 486:	learn: 0.2501722	total: 1.35s	remaining: 1.42s
# 487:	learn: 0.2501100	total: 1.35s	remaining: 1.42s
# 488:	learn: 0.2500928	total: 1.36s	remaining: 1.42s
# 489:	learn: 0.2499923	total: 1.36s	remaining: 1.41s
# 490:	learn: 0.2499399	total: 1.36s	remaining: 1.41s
# 491:	learn: 0.2498917	total: 1.36s	remaining: 1.41s
# 492:	learn: 0.2498229	total: 1.37s	remaining: 1.41s
# 493:	learn: 0.2497884	total: 1.37s	remaining: 1.4s
# 494:	learn: 0.2496540	total: 1.37s	remaining: 1.4s
# 495:	learn: 0.2495615	total: 1.37s	remaining: 1.4s
# 496:	learn: 0.2494761	total: 1.38s	remaining: 1.39s
# 497:	learn: 0.2494000	total: 1.38s	remaining: 1.39s
# 498:	learn: 0.2493232	total: 1.38s	remaining: 1.39s
# 499:	learn: 0.2492348	total: 1.38s	remaining: 1.38s
# 500:	learn: 0.2491794	total: 1.39s	remaining: 1.38s
# 501:	learn: 0.2491098	total: 1.39s	remaining: 1.38s
# 502:	learn: 0.2490513	total: 1.39s	remaining: 1.37s
# 503:	learn: 0.2490442	total: 1.39s	remaining: 1.37s
# 504:	learn: 0.2489814	total: 1.4s	remaining: 1.37s
# 505:	learn: 0.2488905	total: 1.4s	remaining: 1.36s
# 506:	learn: 0.2487562	total: 1.4s	remaining: 1.36s
# 507:	learn: 0.2486462	total: 1.4s	remaining: 1.36s
# 508:	learn: 0.2485938	total: 1.41s	remaining: 1.35s
# 509:	learn: 0.2485379	total: 1.41s	remaining: 1.35s
# 510:	learn: 0.2485199	total: 1.41s	remaining: 1.35s
# 511:	learn: 0.2484978	total: 1.41s	remaining: 1.35s
# 512:	learn: 0.2484021	total: 1.42s	remaining: 1.34s
# 513:	learn: 0.2483692	total: 1.42s	remaining: 1.34s
# 514:	learn: 0.2482282	total: 1.42s	remaining: 1.34s
# 515:	learn: 0.2482091	total: 1.43s	remaining: 1.34s
# 516:	learn: 0.2481107	total: 1.43s	remaining: 1.33s
# 517:	learn: 0.2479747	total: 1.43s	remaining: 1.33s
# 518:	learn: 0.2479561	total: 1.43s	remaining: 1.33s
# 519:	learn: 0.2479383	total: 1.44s	remaining: 1.33s
# 520:	learn: 0.2478417	total: 1.44s	remaining: 1.32s
# 521:	learn: 0.2477334	total: 1.44s	remaining: 1.32s
# 522:	learn: 0.2476334	total: 1.45s	remaining: 1.32s
# 523:	learn: 0.2475391	total: 1.45s	remaining: 1.32s
# 524:	learn: 0.2474618	total: 1.46s	remaining: 1.32s
# 525:	learn: 0.2473012	total: 1.46s	remaining: 1.31s
# 526:	learn: 0.2471715	total: 1.46s	remaining: 1.31s
# 527:	learn: 0.2469987	total: 1.46s	remaining: 1.31s
# 528:	learn: 0.2468559	total: 1.47s	remaining: 1.31s
# 529:	learn: 0.2467601	total: 1.47s	remaining: 1.3s
# 530:	learn: 0.2467047	total: 1.47s	remaining: 1.3s
# 531:	learn: 0.2466409	total: 1.48s	remaining: 1.3s
# 532:	learn: 0.2465259	total: 1.48s	remaining: 1.29s
# 533:	learn: 0.2464895	total: 1.48s	remaining: 1.29s
# 534:	learn: 0.2463633	total: 1.49s	remaining: 1.29s
# 535:	learn: 0.2462142	total: 1.49s	remaining: 1.29s
# 536:	learn: 0.2460949	total: 1.49s	remaining: 1.28s
# 537:	learn: 0.2460304	total: 1.49s	remaining: 1.28s
# 538:	learn: 0.2459948	total: 1.5s	remaining: 1.28s
# 539:	learn: 0.2459830	total: 1.5s	remaining: 1.28s
# 540:	learn: 0.2459318	total: 1.5s	remaining: 1.27s
# 541:	learn: 0.2458109	total: 1.5s	remaining: 1.27s
# 542:	learn: 0.2457974	total: 1.51s	remaining: 1.27s
# 543:	learn: 0.2457564	total: 1.51s	remaining: 1.27s
# 544:	learn: 0.2457213	total: 1.51s	remaining: 1.26s
# 545:	learn: 0.2456384	total: 1.52s	remaining: 1.26s
# 546:	learn: 0.2455815	total: 1.52s	remaining: 1.26s
# 547:	learn: 0.2454782	total: 1.52s	remaining: 1.25s
# 548:	learn: 0.2454470	total: 1.52s	remaining: 1.25s
# 549:	learn: 0.2454296	total: 1.53s	remaining: 1.25s
# 550:	learn: 0.2453877	total: 1.53s	remaining: 1.25s
# 551:	learn: 0.2452860	total: 1.53s	remaining: 1.25s
# 552:	learn: 0.2452719	total: 1.54s	remaining: 1.24s
# 553:	learn: 0.2452660	total: 1.54s	remaining: 1.24s
# 554:	learn: 0.2452475	total: 1.54s	remaining: 1.24s
# 555:	learn: 0.2451582	total: 1.54s	remaining: 1.23s
# 556:	learn: 0.2450881	total: 1.55s	remaining: 1.23s
# 557:	learn: 0.2449757	total: 1.55s	remaining: 1.23s
# 558:	learn: 0.2449505	total: 1.55s	remaining: 1.23s
# 559:	learn: 0.2448810	total: 1.56s	remaining: 1.22s
# 560:	learn: 0.2447963	total: 1.56s	remaining: 1.22s
# 561:	learn: 0.2447657	total: 1.56s	remaining: 1.22s
# 562:	learn: 0.2446808	total: 1.57s	remaining: 1.22s
# 563:	learn: 0.2445906	total: 1.57s	remaining: 1.21s
# 564:	learn: 0.2444951	total: 1.57s	remaining: 1.21s
# 565:	learn: 0.2444793	total: 1.57s	remaining: 1.21s
# 566:	learn: 0.2443863	total: 1.58s	remaining: 1.2s
# 567:	learn: 0.2442570	total: 1.58s	remaining: 1.2s
# 568:	learn: 0.2441675	total: 1.58s	remaining: 1.2s
# 569:	learn: 0.2441650	total: 1.58s	remaining: 1.2s
# 570:	learn: 0.2440823	total: 1.59s	remaining: 1.19s
# 571:	learn: 0.2440655	total: 1.59s	remaining: 1.19s
# 572:	learn: 0.2440505	total: 1.59s	remaining: 1.19s
# 573:	learn: 0.2438960	total: 1.59s	remaining: 1.18s
# 574:	learn: 0.2438721	total: 1.6s	remaining: 1.18s
# 575:	learn: 0.2437468	total: 1.6s	remaining: 1.18s
# 576:	learn: 0.2436890	total: 1.6s	remaining: 1.18s
# 577:	learn: 0.2436350	total: 1.61s	remaining: 1.17s
# 578:	learn: 0.2435338	total: 1.61s	remaining: 1.17s
# 579:	learn: 0.2434818	total: 1.61s	remaining: 1.17s
# 580:	learn: 0.2434584	total: 1.61s	remaining: 1.16s
# 581:	learn: 0.2433808	total: 1.62s	remaining: 1.16s
# 582:	learn: 0.2433028	total: 1.62s	remaining: 1.16s
# 583:	learn: 0.2432452	total: 1.62s	remaining: 1.16s
# 584:	learn: 0.2432273	total: 1.63s	remaining: 1.15s
# 585:	learn: 0.2431354	total: 1.63s	remaining: 1.15s
# 586:	learn: 0.2431216	total: 1.63s	remaining: 1.15s
# 587:	learn: 0.2431062	total: 1.63s	remaining: 1.14s
# 588:	learn: 0.2430909	total: 1.64s	remaining: 1.14s
# 589:	learn: 0.2429763	total: 1.64s	remaining: 1.14s
# 590:	learn: 0.2428575	total: 1.64s	remaining: 1.14s
# 591:	learn: 0.2428115	total: 1.65s	remaining: 1.14s
# 592:	learn: 0.2427965	total: 1.65s	remaining: 1.13s
# 593:	learn: 0.2427418	total: 1.65s	remaining: 1.13s
# 594:	learn: 0.2427328	total: 1.66s	remaining: 1.13s
# 595:	learn: 0.2427216	total: 1.66s	remaining: 1.12s
# 596:	learn: 0.2426367	total: 1.66s	remaining: 1.12s
# 597:	learn: 0.2425528	total: 1.66s	remaining: 1.12s
# 598:	learn: 0.2425479	total: 1.67s	remaining: 1.11s
# 599:	learn: 0.2424431	total: 1.67s	remaining: 1.11s
# 600:	learn: 0.2423838	total: 1.67s	remaining: 1.11s
# 601:	learn: 0.2423581	total: 1.67s	remaining: 1.11s
# 602:	learn: 0.2423504	total: 1.68s	remaining: 1.1s
# 603:	learn: 0.2422340	total: 1.68s	remaining: 1.1s
# 604:	learn: 0.2421490	total: 1.68s	remaining: 1.1s
# 605:	learn: 0.2420463	total: 1.68s	remaining: 1.09s
# 606:	learn: 0.2419462	total: 1.69s	remaining: 1.09s
# 607:	learn: 0.2418716	total: 1.69s	remaining: 1.09s
# 608:	learn: 0.2417890	total: 1.69s	remaining: 1.09s
# 609:	learn: 0.2417168	total: 1.69s	remaining: 1.08s
# 610:	learn: 0.2416203	total: 1.7s	remaining: 1.08s
# 611:	learn: 0.2415532	total: 1.7s	remaining: 1.08s
# 612:	learn: 0.2414247	total: 1.7s	remaining: 1.07s
# 613:	learn: 0.2413097	total: 1.7s	remaining: 1.07s
# 614:	learn: 0.2413007	total: 1.71s	remaining: 1.07s
# 615:	learn: 0.2412744	total: 1.71s	remaining: 1.06s
# 616:	learn: 0.2412078	total: 1.71s	remaining: 1.06s
# 617:	learn: 0.2410959	total: 1.71s	remaining: 1.06s
# 618:	learn: 0.2409635	total: 1.72s	remaining: 1.06s
# 619:	learn: 0.2409412	total: 1.72s	remaining: 1.05s
# 620:	learn: 0.2409267	total: 1.72s	remaining: 1.05s
# 621:	learn: 0.2408565	total: 1.72s	remaining: 1.05s
# 622:	learn: 0.2408018	total: 1.73s	remaining: 1.04s
# 623:	learn: 0.2406956	total: 1.73s	remaining: 1.04s
# 624:	learn: 0.2406069	total: 1.73s	remaining: 1.04s
# 625:	learn: 0.2405392	total: 1.74s	remaining: 1.04s
# 626:	learn: 0.2405136	total: 1.74s	remaining: 1.03s
# 627:	learn: 0.2404272	total: 1.74s	remaining: 1.03s
# 628:	learn: 0.2403462	total: 1.74s	remaining: 1.03s
# 629:	learn: 0.2402231	total: 1.75s	remaining: 1.02s
# 630:	learn: 0.2401618	total: 1.75s	remaining: 1.02s
# 631:	learn: 0.2401545	total: 1.75s	remaining: 1.02s
# 632:	learn: 0.2401406	total: 1.75s	remaining: 1.02s
# 633:	learn: 0.2401330	total: 1.75s	remaining: 1.01s
# 634:	learn: 0.2400694	total: 1.76s	remaining: 1.01s
# 635:	learn: 0.2400457	total: 1.76s	remaining: 1.01s
# 636:	learn: 0.2400221	total: 1.76s	remaining: 1s
# 637:	learn: 0.2399634	total: 1.76s	remaining: 1s
# 638:	learn: 0.2398747	total: 1.77s	remaining: 998ms
# 639:	learn: 0.2398614	total: 1.77s	remaining: 995ms
# 640:	learn: 0.2397773	total: 1.77s	remaining: 992ms
# 641:	learn: 0.2397008	total: 1.77s	remaining: 989ms
# 642:	learn: 0.2396880	total: 1.78s	remaining: 987ms
# 643:	learn: 0.2395999	total: 1.78s	remaining: 984ms
# 644:	learn: 0.2395865	total: 1.78s	remaining: 981ms
# 645:	learn: 0.2394715	total: 1.78s	remaining: 978ms
# 646:	learn: 0.2394629	total: 1.79s	remaining: 975ms
# 647:	learn: 0.2393815	total: 1.79s	remaining: 972ms
# 648:	learn: 0.2392204	total: 1.79s	remaining: 969ms
# 649:	learn: 0.2391204	total: 1.79s	remaining: 966ms
# 650:	learn: 0.2390925	total: 1.8s	remaining: 963ms
# 651:	learn: 0.2389660	total: 1.8s	remaining: 961ms
# 652:	learn: 0.2389576	total: 1.8s	remaining: 958ms
# 653:	learn: 0.2389457	total: 1.8s	remaining: 955ms
# 654:	learn: 0.2388582	total: 1.81s	remaining: 952ms
# 655:	learn: 0.2387911	total: 1.81s	remaining: 949ms
# 656:	learn: 0.2386685	total: 1.81s	remaining: 946ms
# 657:	learn: 0.2385468	total: 1.81s	remaining: 943ms
# 658:	learn: 0.2384974	total: 1.82s	remaining: 940ms
# 659:	learn: 0.2384848	total: 1.82s	remaining: 937ms
# 660:	learn: 0.2384014	total: 1.82s	remaining: 934ms
# 661:	learn: 0.2383761	total: 1.82s	remaining: 932ms
# 662:	learn: 0.2383051	total: 1.83s	remaining: 929ms
# 663:	learn: 0.2381981	total: 1.83s	remaining: 926ms
# 664:	learn: 0.2381862	total: 1.83s	remaining: 923ms
# 665:	learn: 0.2381059	total: 1.83s	remaining: 921ms
# 666:	learn: 0.2379592	total: 1.84s	remaining: 918ms
# 667:	learn: 0.2379517	total: 1.84s	remaining: 915ms
# 668:	learn: 0.2377971	total: 1.84s	remaining: 912ms
# 669:	learn: 0.2376570	total: 1.85s	remaining: 910ms
# 670:	learn: 0.2375923	total: 1.85s	remaining: 907ms
# 671:	learn: 0.2375807	total: 1.85s	remaining: 904ms
# 672:	learn: 0.2374785	total: 1.85s	remaining: 901ms
# 673:	learn: 0.2373907	total: 1.86s	remaining: 898ms
# 674:	learn: 0.2373164	total: 1.86s	remaining: 895ms
# 675:	learn: 0.2372734	total: 1.86s	remaining: 892ms
# 676:	learn: 0.2371256	total: 1.86s	remaining: 889ms
# 677:	learn: 0.2370503	total: 1.87s	remaining: 886ms
# 678:	learn: 0.2369221	total: 1.87s	remaining: 884ms
# 679:	learn: 0.2368541	total: 1.87s	remaining: 881ms
# 680:	learn: 0.2367607	total: 1.87s	remaining: 878ms
# 681:	learn: 0.2367164	total: 1.88s	remaining: 875ms
# 682:	learn: 0.2366389	total: 1.88s	remaining: 872ms
# 683:	learn: 0.2365682	total: 1.88s	remaining: 869ms
# 684:	learn: 0.2364792	total: 1.88s	remaining: 866ms
# 685:	learn: 0.2364056	total: 1.89s	remaining: 863ms
# 686:	learn: 0.2363916	total: 1.89s	remaining: 860ms
# 687:	learn: 0.2363796	total: 1.89s	remaining: 858ms
# 688:	learn: 0.2362772	total: 1.89s	remaining: 855ms
# 689:	learn: 0.2362274	total: 1.9s	remaining: 852ms
# 690:	learn: 0.2361588	total: 1.9s	remaining: 849ms
# 691:	learn: 0.2360549	total: 1.9s	remaining: 846ms
# 692:	learn: 0.2360089	total: 1.9s	remaining: 844ms
# 693:	learn: 0.2359971	total: 1.91s	remaining: 841ms
# 694:	learn: 0.2359531	total: 1.91s	remaining: 838ms
# 695:	learn: 0.2359157	total: 1.91s	remaining: 835ms
# 696:	learn: 0.2358738	total: 1.91s	remaining: 832ms
# 697:	learn: 0.2357960	total: 1.92s	remaining: 829ms
# 698:	learn: 0.2357153	total: 1.92s	remaining: 826ms
# 699:	learn: 0.2357074	total: 1.92s	remaining: 823ms
# 700:	learn: 0.2356080	total: 1.92s	remaining: 821ms
# 701:	learn: 0.2355714	total: 1.93s	remaining: 818ms
# 702:	learn: 0.2355605	total: 1.93s	remaining: 816ms
# 703:	learn: 0.2355490	total: 1.93s	remaining: 813ms
# 704:	learn: 0.2354682	total: 1.94s	remaining: 810ms
# 705:	learn: 0.2353941	total: 1.94s	remaining: 807ms
# 706:	learn: 0.2353030	total: 1.94s	remaining: 805ms
# 707:	learn: 0.2351988	total: 1.95s	remaining: 802ms
# 708:	learn: 0.2351849	total: 1.95s	remaining: 799ms
# 709:	learn: 0.2351014	total: 1.95s	remaining: 797ms
# 710:	learn: 0.2349724	total: 1.95s	remaining: 794ms
# 711:	learn: 0.2348950	total: 1.96s	remaining: 791ms
# 712:	learn: 0.2348124	total: 1.96s	remaining: 788ms
# 713:	learn: 0.2347244	total: 1.96s	remaining: 785ms
# 714:	learn: 0.2347168	total: 1.96s	remaining: 782ms
# 715:	learn: 0.2346639	total: 1.96s	remaining: 779ms
# 716:	learn: 0.2345753	total: 1.97s	remaining: 777ms
# 717:	learn: 0.2345643	total: 1.97s	remaining: 774ms
# 718:	learn: 0.2344781	total: 1.97s	remaining: 771ms
# 719:	learn: 0.2343151	total: 1.97s	remaining: 768ms
# 720:	learn: 0.2342213	total: 1.98s	remaining: 765ms
# 721:	learn: 0.2341461	total: 1.98s	remaining: 762ms
# 722:	learn: 0.2341030	total: 1.98s	remaining: 759ms
# 723:	learn: 0.2340954	total: 1.98s	remaining: 756ms
# 724:	learn: 0.2340120	total: 1.99s	remaining: 753ms
# 725:	learn: 0.2339327	total: 1.99s	remaining: 751ms
# 726:	learn: 0.2338397	total: 1.99s	remaining: 748ms
# 727:	learn: 0.2338266	total: 1.99s	remaining: 745ms
# 728:	learn: 0.2336854	total: 2s	remaining: 742ms
# 729:	learn: 0.2335662	total: 2s	remaining: 739ms
# 730:	learn: 0.2334991	total: 2s	remaining: 736ms
# 731:	learn: 0.2334884	total: 2s	remaining: 734ms
# 732:	learn: 0.2333331	total: 2.01s	remaining: 731ms
# 733:	learn: 0.2332611	total: 2.01s	remaining: 728ms
# 734:	learn: 0.2332419	total: 2.01s	remaining: 725ms
# 735:	learn: 0.2331531	total: 2.01s	remaining: 722ms
# 736:	learn: 0.2330819	total: 2.02s	remaining: 719ms
# 737:	learn: 0.2329931	total: 2.02s	remaining: 717ms
# 738:	learn: 0.2329834	total: 2.02s	remaining: 714ms
# 739:	learn: 0.2329568	total: 2.02s	remaining: 711ms
# 740:	learn: 0.2329497	total: 2.03s	remaining: 708ms
# 741:	learn: 0.2329093	total: 2.03s	remaining: 706ms
# 742:	learn: 0.2328305	total: 2.03s	remaining: 703ms
# 743:	learn: 0.2327830	total: 2.03s	remaining: 700ms
# 744:	learn: 0.2327415	total: 2.04s	remaining: 697ms
# 745:	learn: 0.2326982	total: 2.04s	remaining: 695ms
# 746:	learn: 0.2326232	total: 2.04s	remaining: 692ms
# 747:	learn: 0.2325485	total: 2.06s	remaining: 696ms
# 748:	learn: 0.2324441	total: 2.07s	remaining: 695ms
# 749:	learn: 0.2324018	total: 2.08s	remaining: 692ms
# 750:	learn: 0.2323368	total: 2.08s	remaining: 689ms
# 751:	learn: 0.2322139	total: 2.08s	remaining: 686ms
# 752:	learn: 0.2321555	total: 2.08s	remaining: 683ms
# 753:	learn: 0.2321160	total: 2.08s	remaining: 680ms
# 754:	learn: 0.2320153	total: 2.09s	remaining: 678ms
# 755:	learn: 0.2319481	total: 2.09s	remaining: 675ms
# 756:	learn: 0.2318777	total: 2.09s	remaining: 672ms
# 757:	learn: 0.2317940	total: 2.1s	remaining: 669ms
# 758:	learn: 0.2317871	total: 2.1s	remaining: 666ms
# 759:	learn: 0.2317304	total: 2.1s	remaining: 663ms
# 760:	learn: 0.2316703	total: 2.1s	remaining: 660ms
# 761:	learn: 0.2315600	total: 2.1s	remaining: 658ms
# 762:	learn: 0.2314819	total: 2.11s	remaining: 655ms
# 763:	learn: 0.2314005	total: 2.11s	remaining: 652ms
# 764:	learn: 0.2313616	total: 2.11s	remaining: 649ms
# 765:	learn: 0.2313195	total: 2.12s	remaining: 646ms
# 766:	learn: 0.2312454	total: 2.12s	remaining: 644ms
# 767:	learn: 0.2311642	total: 2.12s	remaining: 641ms
# 768:	learn: 0.2310957	total: 2.12s	remaining: 638ms
# 769:	learn: 0.2310206	total: 2.13s	remaining: 636ms
# 770:	learn: 0.2309801	total: 2.13s	remaining: 633ms
# 771:	learn: 0.2308500	total: 2.13s	remaining: 630ms
# 772:	learn: 0.2307848	total: 2.14s	remaining: 628ms
# 773:	learn: 0.2307786	total: 2.14s	remaining: 625ms
# 774:	learn: 0.2307404	total: 2.14s	remaining: 622ms
# 775:	learn: 0.2306908	total: 2.14s	remaining: 619ms
# 776:	learn: 0.2306649	total: 2.15s	remaining: 616ms
# 777:	learn: 0.2305702	total: 2.15s	remaining: 613ms
# 778:	learn: 0.2305043	total: 2.15s	remaining: 610ms
# 779:	learn: 0.2304940	total: 2.15s	remaining: 608ms
# 780:	learn: 0.2303496	total: 2.16s	remaining: 605ms
# 781:	learn: 0.2302514	total: 2.16s	remaining: 602ms
# 782:	learn: 0.2301920	total: 2.16s	remaining: 599ms
# 783:	learn: 0.2301253	total: 2.16s	remaining: 596ms
# 784:	learn: 0.2300520	total: 2.17s	remaining: 594ms
# 785:	learn: 0.2299347	total: 2.17s	remaining: 591ms
# 786:	learn: 0.2299286	total: 2.17s	remaining: 588ms
# 787:	learn: 0.2298452	total: 2.17s	remaining: 585ms
# 788:	learn: 0.2298333	total: 2.18s	remaining: 582ms
# 789:	learn: 0.2297965	total: 2.18s	remaining: 579ms
# 790:	learn: 0.2297608	total: 2.18s	remaining: 576ms
# 791:	learn: 0.2296981	total: 2.18s	remaining: 574ms
# 792:	learn: 0.2296193	total: 2.19s	remaining: 571ms
# 793:	learn: 0.2295752	total: 2.19s	remaining: 568ms
# 794:	learn: 0.2295153	total: 2.19s	remaining: 565ms
# 795:	learn: 0.2293999	total: 2.19s	remaining: 562ms
# 796:	learn: 0.2293935	total: 2.2s	remaining: 559ms
# 797:	learn: 0.2292878	total: 2.2s	remaining: 557ms
# 798:	learn: 0.2292183	total: 2.2s	remaining: 554ms
# 799:	learn: 0.2291189	total: 2.2s	remaining: 551ms
# 800:	learn: 0.2290682	total: 2.21s	remaining: 548ms
# 801:	learn: 0.2290039	total: 2.21s	remaining: 545ms
# 802:	learn: 0.2289333	total: 2.21s	remaining: 543ms
# 803:	learn: 0.2289234	total: 2.21s	remaining: 540ms
# 804:	learn: 0.2288185	total: 2.22s	remaining: 537ms
# 805:	learn: 0.2287242	total: 2.22s	remaining: 534ms
# 806:	learn: 0.2287145	total: 2.22s	remaining: 531ms
# 807:	learn: 0.2286477	total: 2.22s	remaining: 529ms
# 808:	learn: 0.2285814	total: 2.23s	remaining: 526ms
# 809:	learn: 0.2285719	total: 2.23s	remaining: 523ms
# 810:	learn: 0.2284927	total: 2.23s	remaining: 520ms
# 811:	learn: 0.2283803	total: 2.23s	remaining: 518ms
# 812:	learn: 0.2282140	total: 2.24s	remaining: 515ms
# 813:	learn: 0.2282046	total: 2.24s	remaining: 512ms
# 814:	learn: 0.2281485	total: 2.24s	remaining: 509ms
# 815:	learn: 0.2280946	total: 2.25s	remaining: 506ms
# 816:	learn: 0.2280290	total: 2.25s	remaining: 504ms
# 817:	learn: 0.2278955	total: 2.25s	remaining: 501ms
# 818:	learn: 0.2278613	total: 2.25s	remaining: 498ms
# 819:	learn: 0.2277947	total: 2.26s	remaining: 495ms
# 820:	learn: 0.2277882	total: 2.26s	remaining: 492ms
# 821:	learn: 0.2277527	total: 2.26s	remaining: 490ms
# 822:	learn: 0.2277249	total: 2.26s	remaining: 487ms
# 823:	learn: 0.2276826	total: 2.27s	remaining: 484ms
# 824:	learn: 0.2276269	total: 2.27s	remaining: 482ms
# 825:	learn: 0.2275934	total: 2.27s	remaining: 479ms
# 826:	learn: 0.2275578	total: 2.27s	remaining: 476ms
# 827:	learn: 0.2275085	total: 2.28s	remaining: 473ms
# 828:	learn: 0.2275028	total: 2.28s	remaining: 470ms
# 829:	learn: 0.2274423	total: 2.28s	remaining: 468ms
# 830:	learn: 0.2273217	total: 2.29s	remaining: 465ms
# 831:	learn: 0.2272498	total: 2.29s	remaining: 462ms
# 832:	learn: 0.2271595	total: 2.29s	remaining: 460ms
# 833:	learn: 0.2271369	total: 2.3s	remaining: 457ms
# 834:	learn: 0.2270669	total: 2.3s	remaining: 454ms
# 835:	learn: 0.2270036	total: 2.3s	remaining: 452ms
# 836:	learn: 0.2269950	total: 2.3s	remaining: 449ms
# 837:	learn: 0.2269397	total: 2.31s	remaining: 446ms
# 838:	learn: 0.2268546	total: 2.31s	remaining: 443ms
# 839:	learn: 0.2268148	total: 2.31s	remaining: 440ms
# 840:	learn: 0.2267270	total: 2.31s	remaining: 438ms
# 841:	learn: 0.2266742	total: 2.32s	remaining: 435ms
# 842:	learn: 0.2266045	total: 2.32s	remaining: 432ms
# 843:	learn: 0.2265107	total: 2.32s	remaining: 429ms
# 844:	learn: 0.2263671	total: 2.32s	remaining: 426ms
# 845:	learn: 0.2263036	total: 2.33s	remaining: 424ms
# 846:	learn: 0.2262652	total: 2.33s	remaining: 421ms
# 847:	learn: 0.2261704	total: 2.33s	remaining: 418ms
# 848:	learn: 0.2261618	total: 2.33s	remaining: 415ms
# 849:	learn: 0.2259965	total: 2.34s	remaining: 413ms
# 850:	learn: 0.2259378	total: 2.34s	remaining: 410ms
# 851:	learn: 0.2258801	total: 2.34s	remaining: 407ms
# 852:	learn: 0.2257424	total: 2.35s	remaining: 404ms
# 853:	learn: 0.2256440	total: 2.35s	remaining: 402ms
# 854:	learn: 0.2255638	total: 2.35s	remaining: 399ms
# 855:	learn: 0.2255062	total: 2.35s	remaining: 396ms
# 856:	learn: 0.2254448	total: 2.36s	remaining: 393ms
# 857:	learn: 0.2253679	total: 2.36s	remaining: 391ms
# 858:	learn: 0.2253343	total: 2.36s	remaining: 388ms
# 859:	learn: 0.2253027	total: 2.36s	remaining: 385ms
# 860:	learn: 0.2252505	total: 2.37s	remaining: 382ms
# 861:	learn: 0.2251207	total: 2.37s	remaining: 379ms
# 862:	learn: 0.2251091	total: 2.37s	remaining: 377ms
# 863:	learn: 0.2250720	total: 2.38s	remaining: 374ms
# 864:	learn: 0.2250666	total: 2.38s	remaining: 371ms
# 865:	learn: 0.2249793	total: 2.38s	remaining: 368ms
# 866:	learn: 0.2249630	total: 2.38s	remaining: 365ms
# 867:	learn: 0.2248920	total: 2.38s	remaining: 363ms
# 868:	learn: 0.2248432	total: 2.39s	remaining: 360ms
# 869:	learn: 0.2247815	total: 2.39s	remaining: 357ms
# 870:	learn: 0.2247064	total: 2.39s	remaining: 355ms
# 871:	learn: 0.2246353	total: 2.4s	remaining: 352ms
# 872:	learn: 0.2245439	total: 2.4s	remaining: 349ms
# 873:	learn: 0.2244978	total: 2.4s	remaining: 346ms
# 874:	learn: 0.2244411	total: 2.4s	remaining: 344ms
# 875:	learn: 0.2243962	total: 2.41s	remaining: 341ms
# 876:	learn: 0.2243238	total: 2.41s	remaining: 338ms
# 877:	learn: 0.2242802	total: 2.41s	remaining: 335ms
# 878:	learn: 0.2242073	total: 2.41s	remaining: 332ms
# 879:	learn: 0.2240900	total: 2.42s	remaining: 330ms
# 880:	learn: 0.2239422	total: 2.42s	remaining: 327ms
# 881:	learn: 0.2238527	total: 2.42s	remaining: 324ms
# 882:	learn: 0.2237543	total: 2.42s	remaining: 321ms
# 883:	learn: 0.2237314	total: 2.43s	remaining: 319ms
# 884:	learn: 0.2236349	total: 2.43s	remaining: 316ms
# 885:	learn: 0.2236064	total: 2.43s	remaining: 313ms
# 886:	learn: 0.2235463	total: 2.44s	remaining: 311ms
# 887:	learn: 0.2234770	total: 2.44s	remaining: 308ms
# 888:	learn: 0.2234438	total: 2.44s	remaining: 305ms
# 889:	learn: 0.2233693	total: 2.45s	remaining: 303ms
# 890:	learn: 0.2233641	total: 2.45s	remaining: 300ms
# 891:	learn: 0.2233414	total: 2.45s	remaining: 297ms
# 892:	learn: 0.2232996	total: 2.46s	remaining: 294ms
# 893:	learn: 0.2232946	total: 2.46s	remaining: 292ms
# 894:	learn: 0.2232365	total: 2.46s	remaining: 289ms
# 895:	learn: 0.2231494	total: 2.46s	remaining: 286ms
# 896:	learn: 0.2231248	total: 2.47s	remaining: 283ms
# 897:	learn: 0.2230931	total: 2.47s	remaining: 281ms
# 898:	learn: 0.2230309	total: 2.47s	remaining: 278ms
# 899:	learn: 0.2228830	total: 2.48s	remaining: 275ms
# 900:	learn: 0.2228548	total: 2.48s	remaining: 272ms
# 901:	learn: 0.2227861	total: 2.48s	remaining: 270ms
# 902:	learn: 0.2226217	total: 2.48s	remaining: 267ms
# 903:	learn: 0.2225671	total: 2.49s	remaining: 264ms
# 904:	learn: 0.2224626	total: 2.49s	remaining: 261ms
# 905:	learn: 0.2224545	total: 2.49s	remaining: 259ms
# 906:	learn: 0.2223708	total: 2.49s	remaining: 256ms
# 907:	learn: 0.2223358	total: 2.5s	remaining: 253ms
# 908:	learn: 0.2222911	total: 2.5s	remaining: 250ms
# 909:	learn: 0.2222510	total: 2.5s	remaining: 248ms
# 910:	learn: 0.2222250	total: 2.5s	remaining: 245ms
# 911:	learn: 0.2221415	total: 2.51s	remaining: 242ms
# 912:	learn: 0.2219803	total: 2.51s	remaining: 239ms
# 913:	learn: 0.2218275	total: 2.51s	remaining: 236ms
# 914:	learn: 0.2217078	total: 2.52s	remaining: 234ms
# 915:	learn: 0.2216823	total: 2.52s	remaining: 231ms
# 916:	learn: 0.2216316	total: 2.52s	remaining: 228ms
# 917:	learn: 0.2216225	total: 2.52s	remaining: 225ms
# 918:	learn: 0.2215346	total: 2.53s	remaining: 223ms
# 919:	learn: 0.2214327	total: 2.53s	remaining: 220ms
# 920:	learn: 0.2213362	total: 2.53s	remaining: 217ms
# 921:	learn: 0.2213115	total: 2.54s	remaining: 214ms
# 922:	learn: 0.2212442	total: 2.54s	remaining: 212ms
# 923:	learn: 0.2211888	total: 2.54s	remaining: 209ms
# 924:	learn: 0.2211245	total: 2.54s	remaining: 206ms
# 925:	learn: 0.2210149	total: 2.55s	remaining: 204ms
# 926:	learn: 0.2208800	total: 2.55s	remaining: 201ms
# 927:	learn: 0.2207825	total: 2.55s	remaining: 198ms
# 928:	learn: 0.2206951	total: 2.56s	remaining: 195ms
# 929:	learn: 0.2205759	total: 2.56s	remaining: 193ms
# 930:	learn: 0.2205168	total: 2.56s	remaining: 190ms
# 931:	learn: 0.2204646	total: 2.56s	remaining: 187ms
# 932:	learn: 0.2204138	total: 2.57s	remaining: 184ms
# 933:	learn: 0.2203355	total: 2.57s	remaining: 181ms
# 934:	learn: 0.2202219	total: 2.57s	remaining: 179ms
# 935:	learn: 0.2201747	total: 2.57s	remaining: 176ms
# 936:	learn: 0.2200777	total: 2.58s	remaining: 173ms
# 937:	learn: 0.2199872	total: 2.58s	remaining: 170ms
# 938:	learn: 0.2199528	total: 2.58s	remaining: 168ms
# 939:	learn: 0.2198764	total: 2.58s	remaining: 165ms
# 940:	learn: 0.2198449	total: 2.59s	remaining: 162ms
# 941:	learn: 0.2198255	total: 2.59s	remaining: 159ms
# 942:	learn: 0.2197603	total: 2.59s	remaining: 157ms
# 943:	learn: 0.2196951	total: 2.6s	remaining: 154ms
# 944:	learn: 0.2196588	total: 2.6s	remaining: 151ms
# 945:	learn: 0.2196229	total: 2.6s	remaining: 149ms
# 946:	learn: 0.2195610	total: 2.6s	remaining: 146ms
# 947:	learn: 0.2194886	total: 2.61s	remaining: 143ms
# 948:	learn: 0.2194539	total: 2.61s	remaining: 140ms
# 949:	learn: 0.2194261	total: 2.61s	remaining: 138ms
# 950:	learn: 0.2193690	total: 2.62s	remaining: 135ms
# 951:	learn: 0.2192859	total: 2.62s	remaining: 132ms
# 952:	learn: 0.2192144	total: 2.62s	remaining: 129ms
# 953:	learn: 0.2191648	total: 2.62s	remaining: 126ms
# 954:	learn: 0.2191499	total: 2.63s	remaining: 124ms
# 955:	learn: 0.2190787	total: 2.63s	remaining: 121ms
# 956:	learn: 0.2190159	total: 2.63s	remaining: 118ms
# 957:	learn: 0.2189454	total: 2.63s	remaining: 115ms
# 958:	learn: 0.2189349	total: 2.64s	remaining: 113ms
# 959:	learn: 0.2189242	total: 2.64s	remaining: 110ms
# 960:	learn: 0.2188892	total: 2.64s	remaining: 107ms
# 961:	learn: 0.2188852	total: 2.65s	remaining: 104ms
# 962:	learn: 0.2188355	total: 2.65s	remaining: 102ms
# 963:	learn: 0.2188159	total: 2.65s	remaining: 99ms
# 964:	learn: 0.2187481	total: 2.65s	remaining: 96.2ms
# 965:	learn: 0.2187114	total: 2.65s	remaining: 93.5ms
# 966:	learn: 0.2185986	total: 2.66s	remaining: 90.7ms
# 967:	learn: 0.2185332	total: 2.66s	remaining: 88ms
# 968:	learn: 0.2184487	total: 2.66s	remaining: 85.2ms
# 969:	learn: 0.2183686	total: 2.67s	remaining: 82.5ms
# 970:	learn: 0.2182526	total: 2.67s	remaining: 79.7ms
# 971:	learn: 0.2182423	total: 2.67s	remaining: 76.9ms
# 972:	learn: 0.2181972	total: 2.67s	remaining: 74.2ms
# 973:	learn: 0.2181645	total: 2.67s	remaining: 71.4ms
# 974:	learn: 0.2181193	total: 2.68s	remaining: 68.7ms
# 975:	learn: 0.2180727	total: 2.68s	remaining: 65.9ms
# 976:	learn: 0.2180167	total: 2.68s	remaining: 63.2ms
# 977:	learn: 0.2179194	total: 2.69s	remaining: 60.4ms
# 978:	learn: 0.2178930	total: 2.69s	remaining: 57.7ms
# 979:	learn: 0.2178481	total: 2.69s	remaining: 54.9ms
# 980:	learn: 0.2177902	total: 2.69s	remaining: 52.2ms
# 981:	learn: 0.2177667	total: 2.69s	remaining: 49.4ms
# 982:	learn: 0.2176739	total: 2.7s	remaining: 46.7ms
# 983:	learn: 0.2176403	total: 2.7s	remaining: 43.9ms
# 984:	learn: 0.2175801	total: 2.7s	remaining: 41.2ms
# 985:	learn: 0.2174049	total: 2.71s	remaining: 38.4ms
# 986:	learn: 0.2174002	total: 2.71s	remaining: 35.7ms
# 987:	learn: 0.2173398	total: 2.71s	remaining: 32.9ms
# 988:	learn: 0.2173257	total: 2.71s	remaining: 30.2ms
# 989:	learn: 0.2173157	total: 2.71s	remaining: 27.4ms
# 990:	learn: 0.2172063	total: 2.72s	remaining: 24.7ms
# 991:	learn: 0.2171441	total: 2.72s	remaining: 21.9ms
# 992:	learn: 0.2170676	total: 2.72s	remaining: 19.2ms
# 993:	learn: 0.2170304	total: 2.73s	remaining: 16.4ms
# 994:	learn: 0.2168655	total: 2.73s	remaining: 13.7ms
# 995:	learn: 0.2167853	total: 2.73s	remaining: 11ms
# 996:	learn: 0.2167532	total: 2.73s	remaining: 8.22ms
# 997:	learn: 0.2167038	total: 2.73s	remaining: 5.48ms
# 998:	learn: 0.2166009	total: 2.74s	remaining: 2.74ms
# 999:	learn: 0.2164685	total: 2.74s	remaining: 0us
# 0.9114394110064064 0.8783925001850893
# c:\Users\ksa\stenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 0.8730769230769231

# %% [markdown]
# ## 비교
#
# 정확도 측면에서 성능은 다양한 부스팅 방법에서 매우 일관됩니다. CatBoost는 정확도가 가장 높지만 차이는 미미합니다. 런타임 성능 측면에서 Light Gbm은 실행 속도가 가장 빠르며 정확도도 가장 높습니다.
#
# Gradient Boosting은 런타임 측면에서 잘 수행되지 않았으며 정확도가 가장 낮습니다 (AdaBoost보다 약간 낮음). Light Gbm이이 운동의 챔피언 인 것 같습니다.
#
# ![image.png](attachment:30854d7b-ac21-4f27-9548-95d24889541c.png)

# %% [markdown]
# 개인적으로 성능 / 속도 이점과 모델 튜닝을위한 많은 매개 변수 때문에 Light GBM 및 CatBoost를 사용하는 것이 좋습니다.
#
# 예측 변수에 범주 형 변수가 많을 때 CatBoost가 더 잘 수행됩니다. 범주 형 변수에는 텍스트, 오디오 및 이미지가 포함됩니다. 또한 범주 형 변수를 변환하는 수고를 덜어줍니다.
#
# Light GBM은 CatBoost보다 모델 훈련 속도가 더 빠릅니다. 동시에 정확도 수준을 희생하지 않습니다. 대규모 데이터 세트와 비교적 적은 범주 형 예측 변수가있는 경우 LightGBM을 사용하도록 선택할 수 있습니다.

# %% [markdown]
# 계속 작업
#
# 1. 비교는 30k 행의 데이터에서 수행됩니다. 데이터 세트는 편향 될 수 있으며 크기는 그다지 크지 않습니다. make_classification 패키지 를 사용하여 더 큰 분류 데이터 세트를 사용해 볼 수 있습니다.
# 1. 이 연습은 단지 분류를위한 것이며 회귀 측면을 시도해 볼 수도 있습니다.
# 3. 모델 성능 평가 측면에서 정확도와 런타임 만 사용되며 ROC 점수, F1 점수, 재현율, 정밀도와 같은 다른 분류 평가를 사용하여 전체 그림을 볼 수도 있습니다.
# 4. 모델링에서 가장 시간이 많이 걸리는 부분은 하이퍼 파라미터 튜닝입니다. 현재 연습이나 비교에는 하이퍼 파라미터 튜닝 부분이 포함되지 않았습니다. 나는 그것에 대한 새로운 기사를 가질 것입니다.
#
# 이것은 다양한 유형의 부스팅 방법에 대한 매우 기본적인 개요입니다. 각 방법에 대해 더 많이 읽고 몇 가지 데이터 세트에서 모델을 시도하여 더 이해할 수 있습니다.
#
# 또한 부스팅은 앙상블 학습 알고리즘 중 하나 일뿐입니다. 앙상블 학습에 대해 더 알고 싶다면 아래 기사를 참조하십시오.

# %% [markdown]
# ---
#
# 참고
#  - 혼자 공부하는 머신러닝+딥러닝
