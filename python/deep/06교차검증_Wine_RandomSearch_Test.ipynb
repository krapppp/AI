# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
wine = pd.read_csv('https://raw.githubusercontent.com/rickiepark/hg-mldl/master/wine.csv')
wine.head(3)
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0

# %%
X = wine[['alcohol', 'sugar', 'pH']].to_numpy()
y = wine['class'].to_numpy()

# %%
X.shape, y.shape
# Out:
# ((6497, 3), (6497,))

# %% [markdown]
# 학습 데이터 분할

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=50)

# %%
from scipy.stats import uniform, randint

# %%
params = {
    'min_impurity_decrease' : uniform(0.0001, 0.001),
    'max_depth' : randint(20, 50),
    'min_samples_split' : randint(2, 25),
    'min_samples_leaf' : randint(1, 25)
}

# %% [markdown]
# 샘플링 횟수는 사이킷런의 랜덤 서치 클래스인 RandomizedSearchCV의 n_iter 매개변수에 지정한다.

# %%
from sklearn.model_selection import RandomizedSearchCV

dt_cls =  DecisionTreeClassifier(random_state=50)
gs = RandomizedSearchCV(dt_cls, 
                            params,
                            n_iter=100,
                            n_jobs=-1,
                            random_state=50 
                            )
gs.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=DecisionTreeClassifier(random_state=50),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001B7F5AEA840>,
#                                         'min_impurity_decrease': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001B7F5AEBBC0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001B7F5AE9C10>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001B7F5AEAFF0>},
#                    random_state=50)

# %%
gs.best_params_
# Out:
# {'max_depth': 36,
#  'min_impurity_decrease': np.float64(0.00015640163917149342),
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
dt = gs.best_estimator_  # <-- DescionTreeClass
print(dt.score(X_train, y_train))
# Out:
# 0.938041177602463

# %% [markdown]
# 0.0002 이 가장 좋은 값으로 선택되었다.
#
# 각 매개변수에서 수행한 교차 검증의 평균 점수는 cvresults 속성의 'mean_test_score' 키에 저장되어 있다. 5번의 교차 검증으로 얻은 점수를 출력해보자.

# %%
gs.cv_results_['mean_test_score']
# Out:
# array([0.86934923, 0.86973273, 0.8683875 , 0.86511513, 0.86588325])

# %% [markdown]
# 위처럼 수동으로 고르는 것보다 넘파이의 argmax() 함수를 사용하면 가장 큰 값의 인덱스를 추출할 수 있다. 그 다음 이 인덱스를 사용해 params 키에 저장된 매개변수를 출력할 수 있다.

# %%
idx = np.argmax(gs.cv_results_['mean_test_score'])
gs.cv_results_['params'][idx]
# Out:
# {'min_impurity_decrease': 0.0002}

# %%
wine.min(), wine.max()
# Out:
# (alcohol    8.00
#  sugar      0.60
#  pH         2.72
#  class      0.00
#  dtype: float64,
#  alcohol    14.90
#  sugar      65.80
#  pH          4.01
#  class       1.00
#  dtype: float64)

# %%
wine[wine['class']==0]
# Out:
#       alcohol  sugar    pH  class
# 0         9.4    1.9  3.51    0.0
# 1         9.8    2.6  3.20    0.0
# 2         9.8    2.3  3.26    0.0
# 3         9.8    1.9  3.16    0.0
# 4         9.4    1.9  3.51    0.0
# ...       ...    ...   ...    ...
# 1594     10.5    2.0  3.45    0.0
# 1595     11.2    2.2  3.52    0.0
# 1596     11.0    2.3  3.42    0.0
# 1597     10.2    2.0  3.57    0.0
# 1598     11.0    3.6  3.39    0.0
#
# [1599 rows x 4 columns]

# %%
dt.predict( [[8.0, 0.6, 2.7]])
# dt.predict( [[10.5, 2.1, 3.45]])
# Out:
# array([1.])
